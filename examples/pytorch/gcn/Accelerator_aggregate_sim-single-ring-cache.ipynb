# %%
from queue import Queue
import numpy as np
import math
from operator import itemgetter
from cacheout import Cache

edge_count = 0

class SystolicArrayCell:
    def __init__(self, row_n, col_n):
        self.pos_x = 0
        self.pos_y = 0
        self.row_n = row_n
        self.col_n = col_n
        
        #ring register
        self.receive_cell = None  #接收数据寄存器
        self.receive_reg = 1
        self.receive_out = 0
        #self.send    =   #发送数据寄存器
        
        #On chip buffer
        self.result_bank_input = None
        
        #edge update
        self.process_id = 0
        self.process_id_out = 0
        self.next_src = -1
        self.next_dst = -1
        self.src = -1
        self.dst = -1
        self.rb_depth = 0
        self.rb_value = 0
        self.edge_empty   = False
        self.edge_compute = True
        self.hold         = False
        self.edge_number = 0
        
        self.cache_bank = None

    # Connects this cell to its neighbors above and to the left
    def connect(self, pos_x, pos_y, array):
        self.pos_x = pos_x
        self.pos_y = pos_y
        self.edge_number = pos_y
        #ring dataflow
        if self.pos_y is array.row_n-1:
            self.receive_cell = array.cells[0][self.pos_x] #cell 第一个代表行数，也就是Y， 第二个代表列数，也就是X
        # Otherwise, it's another cell
        else:
            self.receive_cell = array.cells[self.pos_y+1][self.pos_x]
        #each PE on the same row connect to the same result bank
        self.result_bank_input = array.result_bank[self.pos_y][self.pos_x]
        self.edge_bank         = array.edge_bank[self.pos_y]
        self.cache_bank        = array.cache_bank[self.pos_y]

    def set_process_id(self, idx):
        self.process_id = idx
        self.cache_bank.set(idx, 'none')
        
    # We'll model the transfer of signals through registers with a read() and a
    # compute() method. 
    # read() represents the registers sampling data at the positive edge of the
    # clock
    def read(self, edge_update):
        #ring dataflow 
        #print("Enter | cell({:d},{:d}) next_src {:d}, next_dst {:d}, src {:d}, dst {:d}, process_id {:d}". format(self.pos_x, self.pos_y, self.next_src, self.next_dst, self.src, self.dst, self.process_id))
        if self.edge_bank.empty():
            self.edge_empty = True
        elif self.edge_compute or edge_update:
            self.src, self.dst = self.edge_bank.get()
            self.hold         = True
            self.edge_compute = False
        else:
            self.edge_compute = False
        
        if edge_update:
            self.process_id = self.process_id
        else:
            self.receive_reg = self.receive_cell.receive_out
            self.process_id  = self.receive_cell.process_id_out
            self.cache_bank.set(self.process_id,'none')
        
        #print("Medium | cell({:d},{:d}) next_src {:d}, next_dst {:d}, src {:d}, dst {:d}, process_id {:d}". format(self.pos_x, self.pos_y, self.next_src, self.next_dst, self.src, self.dst, self.process_id))
        if self.cache_bank.has(self.src) and self.hold:
            self.edge_compute = True
            self.hold         = False
        else:
            self.edge_compute = False
        '''
        if edge_update:
            if self.edge_bank.empty():
                self.edge_empty = True
                self.hold       = False
            else:
                self.next_src, self.next_dst = self.edge_bank.get()
                self.hold                    = True
        
        if self.next_src == self.process_id and self.hold:
            self.edge_compute = True
            self.src  = self.next_src
            self.dst  = self.next_dst
            self.hold = False
            if self.edge_bank.empty():
                self.edge_empty = True
            else:
                self.next_src, self.next_dst = self.edge_bank.get()
                self.hold = True
        else:
            self.edge_compute = False
        '''
        
        self.rb_depth = int(self.dst/self.row_n)
        #print("Out | cell({:d},{:d}) next_src {:d}, next_dst {:d}, src {:d}, dst {:d}, process_id {:d}". format(self.pos_x, self.pos_y, self.next_src, self.next_dst, self.src, self.dst, self.process_id))
        self.rb_value = self.result_bank_input[self.rb_depth]
        

    # compute() represents combinational logic that takes place between 
    # positive edges of the clock (multiplication and addition)
    def compute(self):
        #ring dataflow
        if self.edge_compute:
            print("compute cell({:d},{:d}) src {:d}, dst {:d}". format(self.pos_x, self.pos_y, self.src, self.dst))
            global edge_count
            edge_count = edge_count + 1
            self.result_bank_input[self.rb_depth] = self.rb_value + self.receive_reg
        self.receive_out = self.receive_reg
        self.process_id_out = self.process_id
        #print("cell({:d},{:d}), hold {:d}, edge_empty {:d}". format(self.pos_x, self.pos_y, self.hold, self.edge_empty))
        #print(self.edge_number)
        
        
    def cell_state(self):
        #print("cell({:d},{:d}),rec_reg={:d}, rec_out={:d}, proc_id={:d}, proc_out={:d}". format(self.pos_x, self.pos_y, self.receive_reg, self.receive_out, self.process_id, self.process_id_out))
        print("cell({:d},{:d}),rec_reg={:d}, proc_id={:d}, rb_value={:d}". format(self.pos_x, self.pos_y, self.receive_reg, self.process_id, self.rb_value))

# %%
# This represents our entire array: cells, inputs, and outputs
class SystolicArray:
    # We'll take a parameter for the size of the square arrays to be multiplied
    def __init__(self, row_n, col_n):
        self.row_n = row_n
        self.col_n = col_n

        # "cells" will hold the array of processing elements
        self.cells = []
        # This array is a square with dimensions "array_size"
        for _ in range(self.row_n):
            row = []
            for _ in range(self.col_n):
                cell = SystolicArrayCell(row_n, col_n)
                row.append(cell)
            self.cells.append(row)
        
        self.cache_bank  = [Cache(maxsize=self.row_n) for _ in range(self.row_n)]
        self.edge_bank   = [Queue() for _ in range(self.row_n)]
        self.result_bank = [[list() for _ in range(self.col_n)] for _ in range(self.row_n)]

        # When all cells and inputs are created, then they can be connected 
        # (again, this would be accomplished with wiring)
        for row_num, row in enumerate(self.cells):
            for col_num, cell in enumerate(row):
                cell.connect(col_num, row_num, self) #每一行对应一个pos_y, 每一列对应一个pos_x
    
    #ring dataflow
    def edge_dual_ring_boardcase(self, row_n, src, dst):
        Edge_list  = [list() for _ in range(row_n)]
        for idx in sorted(zip(src, dst), key=itemgetter(1)):
            src, dst = idx
            Edge_list[dst%row_n].append(idx)
        for idx_, val in enumerate(Edge_list):
            for val_ in sorted(val):
                self.edge_bank[idx_].put(val_)
    
    def edge_bucket_empty(self, e_b):
        for idx in e_b:
            for id_ in idx:
                if id_.empty() is False:
                    return True
        return False

    def edge_load_balance(self, row_n, src, dst):
        Edge_bucket   = [[Queue() for _ in range(row_n)] for _ in range(row_n)]
        for idx in sorted(zip(src, dst)):
            src, dst = idx
            Edge_bucket[src%row_n][dst%row_n].put(idx)
        while(self.edge_bucket_empty(Edge_bucket)):
            for i in range(row_n):
                num = [j for j in range(i,row_n)]
                for n in range(i):
                    num.append(n)
                for id_, val in enumerate(num):
                    #print("--({:d}, {:d})". format(val, id_))
                    if Edge_bucket[val][id_].empty() is False:
                        self.edge_bank[id_].put(Edge_bucket[val][id_].get())
    
    def edge_preprocess(self, num_node, edge_src, edge_dst):
        src, dst = zip(*(sorted(zip(edge_src, edge_dst), key=itemgetter(1))))
        result = [list() for _ in range(num_node)]
        for idx in range(len(dst)):
            result[dst[idx]].append((src[idx],dst[idx]))
        for idx in range(len(result)):
            #print(idx)
            #print(len(result[idx]))
            if len(result[idx]) is 0:
                result[idx] = []
            else:
                src, dst = zip(*result[idx])
                result_A = []
                result_B = []
                for idx_ in range(len(src)):
                    if(src[idx_] >= (dst[idx_]%self.row_n)):
                        result_A.append((src[idx_], dst[idx_]))
                    else:
                        result_B.append((src[idx_], dst[idx_]))
                result_A.extend(result_B)
                result[idx] = result_A
        return result

    def fill_edges(self, num_node, edge_src, edge_dst):
        edge_ = self.edge_preprocess(num_node, edge_src, edge_dst)
        for i, val in enumerate(edge_):
            for e in val:
                self.edge_bank[i%self.row_n].put(e)
                
    def fill_result_banks(self, num_nodes):
        for row_num in range(self.row_n):
            for idx_ in range(self.col_n):  
                for _ in range(math.ceil(num_nodes/self.row_n)):
                    self.result_bank[row_num][idx_].append(0)
                    
    def fill_idx(self,idx):
        for row_num in range(self.row_n):
            for col_num in range(self.col_n):
                self.cells[row_num][col_num].set_process_id(idx[row_num])
    
    # For this demo, all cells will read() the values of their neighbors first
    def read(self,edge_update):
        for row in self.cells:
            for cell in row:
                cell.read(edge_update)

    # And then after all cells have read(), they will compute() the next step
    def compute(self):
        for row in self.cells:
            for cell in row:
                cell.compute()
                
    def terminal_signal(self):
        for row in self.cells:
            for cell in row:
                #print(cell.hold)
                #print(cell.edge_bank.empty())
                if cell.hold or not cell.edge_empty:
                    return False
        return True
        #for id_x in self.edge_bank:
        #    if id_x.empty() is False:
        #        return False
        #return True
            
            
    def show_staus(self):
        for row in self.cells:
            for cell in row:
                cell.cell_state()
                
    # Each cycle involves a read() and a compute()
    def cycle(self, edge_update):
        # read() models register sampling on the positive edge of the clock
        self.read(edge_update)
        # compute() models the combinational logic between clock edges
        self.compute()
        #self.show_staus()

    # run() will execute the array's computation, assuming it's been filled
    def run(self, num_nodes):
        # It takes 3n-2 cycles to compute the full matrix of results
        edge_update = True
        cycle = 0
        while 1:
            print("-----Cycle----{:d}----------". format(cycle))
            self.cycle(edge_update)
            edge_update = False
            #self.get_edge_output(num_nodes)
            if(self.terminal_signal()):
                break
            cycle = cycle + 1
        return cycle
        #return self.get_outputs()

    # The outputs are also staggered and transposed, so we'll format them 
    # before returning the results
    def get_outputs(self):
        ret = []

        return ret

    def get_edge_output(self, num_nodes):
        for id_x in range(num_nodes):
            print("id={:d}-|-{:d}". format(id_x, self.result_bank[int(id_x%self.row_n)][0][int(id_x/self.row_n)]))

# %%
# Here we'll use a small 3x3 test multiplication to see the systolic array
# in action
row_n = 3
col_n = 1
myArray = SystolicArray(row_n, col_n)

#src = [0,1,2,1,2,0,2,0,1]
#dst = [0,1,2,0,1,2,0,1,2]

#src = [0,0,0,0,1,1,2,2,2]
#dst = [0,1,3,5,2,4,0,3,5]

src = [0,1,1,2,0,0,0,2,2]
dst = [0,2,4,0,1,3,5,3,5]

#src = [0,1,1,2,0,1,0,2,2]
#dst = [0,2,4,0,1,3,5,4,5]

#src = [0,0,1,2]
#dst = [0,1,2,0]

#myArray.fill_edges(6, src, dst)
#myArray.edge_load_balance(row_n, src, dst)
myArray.edge_dual_ring_boardcase(row_n, src, dst)
idx = [0,1,2]
myArray.fill_idx(idx)
myArray.fill_result_banks(6)       

res = myArray.run(6)
#assert (res == np.matmul(activations, weights)).all()
#print('Systolic array matches numpy matmul')
# Out:
# -----Cycle----0----------
# compute cell(0,0) src 0, dst 0
# -----Cycle----1----------
# compute cell(0,0) src 0, dst 3
# compute cell(0,2) src 0, dst 5
# -----Cycle----2----------
# compute cell(0,0) src 2, dst 0
# compute cell(0,1) src 0, dst 1
# compute cell(0,2) src 1, dst 2
# -----Cycle----3----------
# compute cell(0,0) src 2, dst 3
# compute cell(0,1) src 1, dst 4
# compute cell(0,2) src 2, dst 5
# -----Cycle----4----------

# %%
import argparse, time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from dgl import DGLGraph
from dgl import graph_index
from dgl.graph_index import disjoint_partition
from dgl.data import register_data_args, load_data
import math

# %%
    parser = argparse.ArgumentParser(description='GCN')
    parser.add_argument("--dataset", type=str, default="cora",
            help="dropout probability")
    parser.add_argument("--dropout", type=float, default=0.5,
            help="dropout probability")
    parser.add_argument("--gpu", type=int, default=-1,
            help="gpu")
    parser.add_argument("--lr", type=float, default=1e-2,
            help="learning rate")
    parser.add_argument("--n-epochs", type=int, default=200,
            help="number of training epochs")
    parser.add_argument("--n-hidden", type=int, default=16,
            help="number of hidden gcn units")
    parser.add_argument("--n-layers", type=int, default=1,
            help="number of hidden gcn layers")
    parser.add_argument("--weight-decay", type=float, default=5e-4,
            help="Weight for L2 loss")
    parser.add_argument("--self-loop", action='store_true',
            help="graph self-loop (default=False)")
    parser.set_defaults(self_loop=False)
    args = parser.parse_args(args=[])

# %%
    data = load_data(args)
    features = torch.FloatTensor(data.features)
    labels = torch.LongTensor(data.labels)
    train_mask = torch.ByteTensor(data.train_mask)
    val_mask = torch.ByteTensor(data.val_mask)
    test_mask = torch.ByteTensor(data.test_mask)
    in_feats = features.shape[1]
    n_classes = data.num_labels
    n_edges = data.graph.number_of_edges()

# %%
g = DGLGraph(data.graph)

# %%
partition_size = 32
Node_index = []
Edge = []
Edge_number = []
partition_number = math.ceil(g.number_of_nodes() / partition_size)
print("the graph split to {:d} part". format(partition_number))
for node_id in range(partition_number):
    #print(node_id)
    if node_id == partition_number-1:
        index = list(range(partition_size*node_id,g.number_of_nodes()))
    else:
        index = list(range(partition_size*node_id,partition_size*(node_id+1)))
    Node_index.append(index)
    src, dst = g.out_edges(index)
    Edge.append(list(zip(src.tolist(),dst.tolist())))
    Edge_number.append(src.shape[0])
# Out:
# the graph split to 85 part

# %%
src, dst = zip(*Edge[1])

# %%
len(Edge[1])
# Out:
# 129

# %%
idx = Node_index[1]

# %%
edge_count = 0
row_n = 32
col_n = 1
cycle_list = []
for i, val in enumerate(Edge):
    src, dst = zip(*val)
    idx = Node_index[i]
    for i in range(len(idx),32):
        idx.append(0)
    myArray = SystolicArray(row_n, col_n)
    myArray.edge_load_balance(row_n, src, dst)
    myArray.fill_idx(idx)
    myArray.fill_result_banks(2708)       
    res = myArray.run(2708)
    cycle_list.append(res)
# Out:
# -----Cycle----0----------
# compute cell(0,0) src 0, dst 544
# compute cell(0,15) src 15, dst 399
# compute cell(0,23) src 23, dst 759
# -----Cycle----1----------
# compute cell(0,29) src 30, dst 285
# -----Cycle----2----------
# compute cell(0,12) src 14, dst 268
# compute cell(0,28) src 30, dst 1148
# -----Cycle----3----------
# compute cell(0,7) src 10, dst 519
# compute cell(0,28) src 31, dst 1116
# -----Cycle----4----------
# compute cell(0,5) src 9, dst 453
# compute cell(0,10) src 14, dst 746
# -----Cycle----5----------
# compute cell(0,2) src 7, dst 258
# compute cell(0,9) src 14, dst 393
# compute cell(0,10) src 15, dst 234
# compute cell(0,17) src 22, dst 2257
# compute cell(0,20) src 25, dst 20
# compute cell(0,26) src 31, dst 250
# -----Cycle----6----------
# compute cell(0,2) src 8, dst 258
# compute cell(0,4) src 10, dst 420
# compute cell(0,8) src 14, dst 8
# compute cell(0,12) src 18, dst 1932
# compute cell(0,14) src 20, dst 334
# compute cell(0,20) src 26, dst 2612
# compute cell(0,22) src 28, dst 1718
# -----Cycle----7----------
# compute cell(0,11) src 18, dst 427
# compute cell(0,20) src 27, dst 84
# -----Cycle----8----------
# compute cell(0,0) src 8, dst 0
# compute cell(0,1) src 9, dst 481
# compute cell(0,8) src 16, dst 552
# compute cell(0,26) src 2, dst 410
# -----Cycle----9----------
# compute cell(0,1) src 10, dst 193
# compute cell(0,5) src 14, dst 613
# compute cell(0,9) src 18, dst 745
# compute cell(0,10) src 19, dst 74
# compute cell(0,11) src 20, dst 267
# compute cell(0,24) src 1, dst 344
# -----Cycle----10----------
# compute cell(0,0) src 10, dst 192
# compute cell(0,4) src 14, dst 708
# compute cell(0,25) src 3, dst 601
# -----Cycle----11----------
# compute cell(0,2) src 13, dst 482
# compute cell(0,13) src 24, dst 269
# compute cell(0,23) src 2, dst 471
# compute cell(0,27) src 6, dst 251
# -----Cycle----12----------
# compute cell(0,2) src 14, dst 258
# -----Cycle----13----------
# compute cell(0,2) src 15, dst 322
# compute cell(0,19) src 0, dst 435
# compute cell(0,21) src 2, dst 565
# -----Cycle----14----------
# compute cell(0,0) src 14, dst 0
# compute cell(0,1) src 15, dst 129
# compute cell(0,9) src 23, dst 41
# -----Cycle----15----------
# compute cell(0,1) src 16, dst 1697
# compute cell(0,6) src 21, dst 294
# compute cell(0,10) src 25, dst 778
# compute cell(0,11) src 26, dst 747
# compute cell(0,31) src 14, dst 31
# -----Cycle----16----------
# compute cell(0,2) src 18, dst 866
# compute cell(0,9) src 25, dst 1897
# compute cell(0,11) src 18, dst 747
# compute cell(0,13) src 29, dst 429
# compute cell(0,25) src 9, dst 761
# -----Cycle----17----------
# compute cell(0,7) src 24, dst 39
# compute cell(0,8) src 25, dst 456
# compute cell(0,9) src 26, dst 1129
# compute cell(0,14) src 31, dst 14
# compute cell(0,20) src 5, dst 2164
# compute cell(0,27) src 12, dst 155
# compute cell(0,30) src 15, dst 254
# -----Cycle----18----------
# compute cell(0,10) src 28, dst 586
# compute cell(0,14) src 0, dst 14
# compute cell(0,24) src 10, dst 280
# compute cell(0,29) src 15, dst 253
# -----Cycle----19----------
# compute cell(0,2) src 21, dst 1378
# compute cell(0,3) src 22, dst 163
# compute cell(0,10) src 29, dst 426
# compute cell(0,27) src 14, dst 443
# compute cell(0,31) src 18, dst 127
# -----Cycle----20----------
# compute cell(0,0) src 20, dst 640
# compute cell(0,15) src 3, dst 463
# -----Cycle----21----------
# compute cell(0,0) src 14, dst 384
# compute cell(0,1) src 22, dst 129
# compute cell(0,19) src 8, dst 435
# compute cell(0,20) src 9, dst 308
# compute cell(0,26) src 15, dst 538
# -----Cycle----22----------
# compute cell(0,0) src 14, dst 544
# compute cell(0,6) src 28, dst 1606
# -----Cycle----23----------
# compute cell(0,0) src 14, dst 736
# compute cell(0,7) src 30, dst 231
# compute cell(0,24) src 15, dst 152
# compute cell(0,31) src 22, dst 191
# -----Cycle----24----------
# compute cell(0,7) src 30, dst 679
# compute cell(0,8) src 0, dst 8
# compute cell(0,19) src 11, dst 659
# compute cell(0,20) src 12, dst 84
# compute cell(0,26) src 18, dst 890
# compute cell(0,27) src 19, dst 571
# compute cell(0,28) src 20, dst 732
# compute cell(0,30) src 22, dst 1790
# -----Cycle----25----------
# compute cell(0,3) src 28, dst 611
# compute cell(0,15) src 8, dst 751
# compute cell(0,20) src 27, dst 532
# compute cell(0,21) src 14, dst 437
# -----Cycle----26----------
# compute cell(0,4) src 30, dst 2276
# compute cell(0,8) src 2, dst 552
# compute cell(0,10) src 4, dst 170
# compute cell(0,14) src 8, dst 14
# compute cell(0,22) src 16, dst 566
# -----Cycle----27----------
# compute cell(0,8) src 14, dst 232
# compute cell(0,10) src 5, dst 490
# compute cell(0,16) src 11, dst 624
# compute cell(0,18) src 13, dst 1234
# compute cell(0,19) src 14, dst 435
# compute cell(0,25) src 20, dst 25
# -----Cycle----28----------
# compute cell(0,10) src 6, dst 490
# compute cell(0,18) src 14, dst 242
# compute cell(0,29) src 25, dst 1181
# -----Cycle----29----------
# compute cell(0,29) src 15, dst 701
# -----Cycle----30----------
# compute cell(0,2) src 0, dst 258
# compute cell(0,5) src 3, dst 197
# compute cell(0,16) src 14, dst 400
# compute cell(0,18) src 16, dst 466
# compute cell(0,23) src 21, dst 567
# compute cell(0,31) src 29, dst 319
# -----Cycle----31----------
# compute cell(0,2) src 13, dst 578
# compute cell(0,15) src 14, dst 751
# compute cell(0,16) src 15, dst 80
# compute cell(0,18) src 17, dst 146
# compute cell(0,22) src 21, dst 438
# compute cell(0,30) src 29, dst 382
# -----Cycle----32----------
# -----Cycle----0----------
# compute cell(0,2) src 34, dst 66
# compute cell(0,11) src 43, dst 747
# compute cell(0,14) src 46, dst 238
# compute cell(0,20) src 52, dst 2580
# compute cell(0,28) src 60, dst 252
# -----Cycle----1----------
# compute cell(0,2) src 35, dst 34
# compute cell(0,12) src 45, dst 492
# compute cell(0,13) src 46, dst 301
# compute cell(0,26) src 59, dst 570
# -----Cycle----2----------
# compute cell(0,19) src 53, dst 243
# compute cell(0,24) src 58, dst 536
# -----Cycle----3----------
# compute cell(0,1) src 36, dst 257
# compute cell(0,10) src 45, dst 490
# -----Cycle----4----------
# compute cell(0,5) src 41, dst 1733
# compute cell(0,21) src 57, dst 565
# -----Cycle----5----------
# compute cell(0,9) src 46, dst 489
# compute cell(0,25) src 62, dst 2425
# -----Cycle----6----------
# compute cell(0,14) src 52, dst 430
# compute cell(0,17) src 55, dst 1905
# compute cell(0,19) src 57, dst 1459
# compute cell(0,25) src 63, dst 153
# -----Cycle----7----------
# compute cell(0,3) src 42, dst 163
# compute cell(0,18) src 57, dst 306
# compute cell(0,21) src 60, dst 565
# compute cell(0,26) src 33, dst 250
# -----Cycle----8----------
# -----Cycle----9----------
# compute cell(0,0) src 41, dst 352
# -----Cycle----10----------
# compute cell(0,18) src 60, dst 562
# compute cell(0,23) src 33, dst 1591
# -----Cycle----11----------
# compute cell(0,0) src 43, dst 576
# compute cell(0,3) src 46, dst 867
# compute cell(0,7) src 50, dst 583
# compute cell(0,11) src 54, dst 523
# compute cell(0,12) src 55, dst 844
# compute cell(0,16) src 59, dst 1520
# compute cell(0,27) src 38, dst 219
# compute cell(0,30) src 41, dst 94
# -----Cycle----12----------
# compute cell(0,5) src 49, dst 581
# compute cell(0,16) src 60, dst 688
# compute cell(0,22) src 34, dst 566
# compute cell(0,24) src 36, dst 2072
# -----Cycle----13----------
# compute cell(0,5) src 50, dst 581
# compute cell(0,16) src 61, dst 240
# compute cell(0,17) src 62, dst 945
# compute cell(0,18) src 63, dst 210
# compute cell(0,21) src 34, dst 565
# compute cell(0,23) src 36, dst 1591
# compute cell(0,25) src 38, dst 1689
# compute cell(0,28) src 41, dst 892
# compute cell(0,29) src 42, dst 189
# -----Cycle----14----------
# compute cell(0,3) src 49, dst 643
# compute cell(0,5) src 51, dst 645
# compute cell(0,8) src 54, dst 712
# compute cell(0,9) src 55, dst 361
# compute cell(0,10) src 56, dst 778
# compute cell(0,13) src 59, dst 1709
# compute cell(0,22) src 36, dst 1974
# compute cell(0,28) src 42, dst 188
# -----Cycle----15----------
# compute cell(0,3) src 50, dst 643
# compute cell(0,4) src 51, dst 772
# compute cell(0,7) src 54, dst 615
# compute cell(0,8) src 55, dst 1832
# compute cell(0,24) src 39, dst 24
# compute cell(0,25) src 40, dst 761
# -----Cycle----16----------
# compute cell(0,4) src 52, dst 228
# compute cell(0,25) src 41, dst 889
# compute cell(0,28) src 44, dst 2428
# -----Cycle----17----------
# compute cell(0,7) src 56, dst 967
# compute cell(0,8) src 57, dst 552
# compute cell(0,10) src 59, dst 874
# compute cell(0,24) src 41, dst 888
# compute cell(0,25) src 42, dst 793
# compute cell(0,28) src 45, dst 220
# -----Cycle----18----------
# compute cell(0,3) src 53, dst 803
# compute cell(0,7) src 57, dst 967
# compute cell(0,12) src 62, dst 332
# compute cell(0,19) src 37, dst 563
# compute cell(0,20) src 38, dst 372
# compute cell(0,23) src 41, dst 23
# -----Cycle----19----------
# compute cell(0,8) src 59, dst 872
# compute cell(0,15) src 34, dst 559
# compute cell(0,19) src 38, dst 563
# -----Cycle----20----------
# compute cell(0,3) src 55, dst 163
# compute cell(0,7) src 59, dst 839
# compute cell(0,8) src 60, dst 552
# compute cell(0,10) src 62, dst 2474
# compute cell(0,21) src 41, dst 533
# compute cell(0,24) src 44, dst 88
# compute cell(0,31) src 51, dst 2559
# -----Cycle----21----------
# compute cell(0,3) src 56, dst 1027
# compute cell(0,10) src 63, dst 1546
# compute cell(0,17) src 38, dst 273
# compute cell(0,18) src 39, dst 82
# compute cell(0,20) src 41, dst 1716
# -----Cycle----22----------
# compute cell(0,19) src 41, dst 115
# compute cell(0,26) src 48, dst 2682
# compute cell(0,30) src 52, dst 478
# compute cell(0,31) src 53, dst 1439
# -----Cycle----23----------
# compute cell(0,3) src 58, dst 1891
# compute cell(0,7) src 62, dst 423
# compute cell(0,13) src 36, dst 1933
# -----Cycle----24----------
# compute cell(0,6) src 62, dst 2566
# compute cell(0,17) src 41, dst 1713
# compute cell(0,23) src 47, dst 87
# compute cell(0,24) src 48, dst 2456
# compute cell(0,30) src 54, dst 2334
# -----Cycle----25----------
# compute cell(0,7) src 32, dst 679
# compute cell(0,23) src 48, dst 1783
# -----Cycle----26----------
# compute cell(0,4) src 62, dst 324
# compute cell(0,10) src 36, dst 1066
# compute cell(0,19) src 45, dst 1459
# compute cell(0,27) src 53, dst 1563
# -----Cycle----27----------
# compute cell(0,0) src 59, dst 576
# compute cell(0,9) src 36, dst 745
# compute cell(0,21) src 48, dst 725
# compute cell(0,31) src 58, dst 2495
# -----Cycle----28----------
# compute cell(0,3) src 63, dst 739
# compute cell(0,5) src 33, dst 1701
# compute cell(0,21) src 41, dst 725
# compute cell(0,22) src 50, dst 150
# compute cell(0,30) src 58, dst 990
# -----Cycle----29----------
# compute cell(0,22) src 36, dst 2390
# compute cell(0,23) src 52, dst 2487
# compute cell(0,30) src 41, dst 1982
# -----Cycle----30----------
# compute cell(0,14) src 44, dst 686
# -----Cycle----31----------
# compute cell(0,3) src 34, dst 35
# compute cell(0,5) src 36, dst 1701
# compute cell(0,23) src 54, dst 1687
# compute cell(0,24) src 55, dst 1784
# -----Cycle----32----------
# compute cell(0,24) src 41, dst 2456
# -----Cycle----33----------
# -----Cycle----0----------
# compute cell(0,2) src 66, dst 34
# compute cell(0,10) src 74, dst 906
# compute cell(0,12) src 76, dst 1548
# compute cell(0,21) src 85, dst 565
# compute cell(0,24) src 88, dst 760
# compute cell(0,30) src 94, dst 126
# -----Cycle----1----------
# compute cell(0,10) src 75, dst 1354
# compute cell(0,15) src 80, dst 15
# compute cell(0,17) src 82, dst 305
# compute cell(0,21) src 86, dst 373
# -----Cycle----2----------
# compute cell(0,0) src 66, dst 288
# compute cell(0,5) src 71, dst 677
# compute cell(0,8) src 74, dst 680
# -----Cycle----3----------
# compute cell(0,1) src 68, dst 1825
# compute cell(0,2) src 69, dst 66
# compute cell(0,3) src 70, dst 931
# compute cell(0,7) src 74, dst 71
# compute cell(0,15) src 82, dst 239
# -----Cycle----4----------
# compute cell(0,0) src 68, dst 1632
# compute cell(0,2) src 70, dst 1986
# compute cell(0,3) src 71, dst 1923
# compute cell(0,8) src 76, dst 392
# compute cell(0,17) src 85, dst 465
# compute cell(0,20) src 88, dst 116
# compute cell(0,28) src 64, dst 284
# -----Cycle----5----------
# compute cell(0,3) src 72, dst 771
# compute cell(0,19) src 88, dst 371
# -----Cycle----6----------
# compute cell(0,1) src 71, dst 929
# compute cell(0,4) src 74, dst 1220
# compute cell(0,6) src 76, dst 518
# compute cell(0,14) src 84, dst 1550
# compute cell(0,23) src 93, dst 759
# -----Cycle----7----------
# compute cell(0,3) src 74, dst 547
# compute cell(0,5) src 76, dst 869
# compute cell(0,21) src 92, dst 565
# compute cell(0,27) src 66, dst 1531
# compute cell(0,31) src 70, dst 255
# -----Cycle----8----------
# compute cell(0,2) src 74, dst 1634
# compute cell(0,3) src 75, dst 1123
# compute cell(0,4) src 76, dst 2532
# compute cell(0,11) src 83, dst 747
# compute cell(0,12) src 84, dst 12
# compute cell(0,15) src 87, dst 47
# compute cell(0,16) src 88, dst 208
# compute cell(0,21) src 93, dst 725
# compute cell(0,23) src 95, dst 759
# -----Cycle----9----------
# compute cell(0,1) src 74, dst 193
# compute cell(0,3) src 76, dst 131
# compute cell(0,11) src 84, dst 715
# compute cell(0,27) src 68, dst 1979
# -----Cycle----10----------
# compute cell(0,0) src 74, dst 1024
# compute cell(0,7) src 81, dst 647
# compute cell(0,12) src 86, dst 652
# compute cell(0,24) src 66, dst 2520
# compute cell(0,25) src 67, dst 729
# compute cell(0,28) src 70, dst 1692
# -----Cycle----11----------
# compute cell(0,0) src 75, dst 288
# compute cell(0,7) src 82, dst 39
# compute cell(0,14) src 89, dst 430
# compute cell(0,23) src 66, dst 183
# compute cell(0,31) src 74, dst 511
# -----Cycle----12----------
# compute cell(0,9) src 85, dst 425
# compute cell(0,12) src 88, dst 44
# compute cell(0,22) src 66, dst 2294
# compute cell(0,30) src 74, dst 2654
# compute cell(0,31) src 75, dst 1855
# -----Cycle----13----------
# compute cell(0,6) src 83, dst 294
# compute cell(0,8) src 85, dst 552
# compute cell(0,11) src 88, dst 587
# compute cell(0,21) src 66, dst 149
# compute cell(0,23) src 68, dst 2007
# compute cell(0,29) src 74, dst 2013
# compute cell(0,30) src 75, dst 1854
# -----Cycle----14----------
# compute cell(0,4) src 82, dst 548
# compute cell(0,6) src 84, dst 998
# compute cell(0,10) src 88, dst 682
# compute cell(0,28) src 74, dst 252
# -----Cycle----15----------
# compute cell(0,6) src 85, dst 294
# compute cell(0,21) src 68, dst 1845
# compute cell(0,27) src 74, dst 987
# -----Cycle----16----------
# compute cell(0,2) src 82, dst 1378
# compute cell(0,11) src 91, dst 747
# compute cell(0,23) src 71, dst 1559
# compute cell(0,26) src 74, dst 154
# compute cell(0,27) src 75, dst 2299
# compute cell(0,30) src 78, dst 766
# compute cell(0,31) src 79, dst 2207
# -----Cycle----17----------
# compute cell(0,2) src 66, dst 1698
# compute cell(0,3) src 84, dst 1347
# compute cell(0,11) src 92, dst 1259
# compute cell(0,19) src 68, dst 979
# compute cell(0,25) src 74, dst 345
# compute cell(0,29) src 78, dst 157
# -----Cycle----18----------
# compute cell(0,0) src 82, dst 1440
# compute cell(0,3) src 74, dst 867
# compute cell(0,5) src 87, dst 2021
# compute cell(0,8) src 90, dst 680
# compute cell(0,9) src 91, dst 745
# compute cell(0,21) src 71, dst 661
# compute cell(0,26) src 76, dst 250
# -----Cycle----19----------
# compute cell(0,25) src 76, dst 345
# -----Cycle----20----------
# compute cell(0,8) src 92, dst 136
# compute cell(0,22) src 74, dst 310
# compute cell(0,28) src 80, dst 2044
# -----Cycle----21----------
# compute cell(0,0) src 85, dst 2368
# compute cell(0,9) src 94, dst 41
# compute cell(0,13) src 66, dst 2157
# compute cell(0,17) src 70, dst 1521
# compute cell(0,21) src 74, dst 661
# compute cell(0,23) src 76, dst 2327
# compute cell(0,25) src 78, dst 2681
# compute cell(0,28) src 74, dst 604
# -----Cycle----22----------
# compute cell(0,0) src 66, dst 1248
# compute cell(0,6) src 92, dst 2438
# compute cell(0,22) src 76, dst 694
# compute cell(0,23) src 66, dst 215
# -----Cycle----23----------
# compute cell(0,1) src 88, dst 225
# compute cell(0,19) src 74, dst 19
# compute cell(0,21) src 76, dst 181
# compute cell(0,23) src 66, dst 2359
# compute cell(0,31) src 86, dst 735
# -----Cycle----24----------
# compute cell(0,7) src 95, dst 1255
# compute cell(0,10) src 66, dst 2122
# compute cell(0,19) src 74, dst 787
# compute cell(0,22) src 78, dst 214
# compute cell(0,26) src 82, dst 410
# compute cell(0,31) src 87, dst 383
# -----Cycle----25----------
# compute cell(0,6) src 95, dst 358
# compute cell(0,7) src 64, dst 583
# compute cell(0,8) src 65, dst 744
# compute cell(0,9) src 66, dst 2441
# compute cell(0,17) src 74, dst 881
# compute cell(0,21) src 78, dst 469
# compute cell(0,22) src 79, dst 438
# compute cell(0,27) src 84, dst 27
# -----Cycle----26----------
# compute cell(0,6) src 64, dst 486
# compute cell(0,7) src 65, dst 743
# compute cell(0,8) src 74, dst 1928
# compute cell(0,10) src 68, dst 522
# -----Cycle----27----------
# compute cell(0,8) src 76, dst 1128
# compute cell(0,15) src 74, dst 975
# compute cell(0,25) src 84, dst 1241
# compute cell(0,30) src 89, dst 638
# -----Cycle----28----------
# compute cell(0,6) src 66, dst 2310
# compute cell(0,8) src 92, dst 552
# compute cell(0,14) src 74, dst 622
# compute cell(0,17) src 77, dst 337
# compute cell(0,24) src 84, dst 1240
# -----Cycle----29----------
# compute cell(0,5) src 66, dst 69
# compute cell(0,10) src 71, dst 74
# compute cell(0,11) src 72, dst 747
# compute cell(0,15) src 76, dst 975
# compute cell(0,17) src 82, dst 1553
# compute cell(0,21) src 82, dst 565
# compute cell(0,25) src 86, dst 249
# compute cell(0,27) src 88, dst 251
# compute cell(0,31) src 92, dst 479
# -----Cycle----30----------
# compute cell(0,1) src 95, dst 161
# compute cell(0,5) src 87, dst 2245
# compute cell(0,9) src 71, dst 1641
# compute cell(0,10) src 72, dst 202
# compute cell(0,11) src 73, dst 747
# compute cell(0,12) src 74, dst 1676
# compute cell(0,14) src 76, dst 1934
# compute cell(0,15) src 87, dst 719
# compute cell(0,16) src 78, dst 560
# compute cell(0,17) src 74, dst 2513
# compute cell(0,21) src 74, dst 949
# compute cell(0,22) src 84, dst 950
# compute cell(0,25) src 74, dst 377
# compute cell(0,26) src 88, dst 762
# compute cell(0,27) src 89, dst 635
# compute cell(0,31) src 74, dst 2335
# -----Cycle----31----------
# compute cell(0,1) src 64, dst 289
# compute cell(0,7) src 70, dst 999
# compute cell(0,9) src 72, dst 745
# compute cell(0,10) src 75, dst 2122
# compute cell(0,11) src 84, dst 1803
# compute cell(0,12) src 74, dst 2124
# compute cell(0,15) src 74, dst 1103
# compute cell(0,21) src 76, dst 661
# compute cell(0,22) src 74, dst 2390
# compute cell(0,25) src 74, dst 505
# compute cell(0,26) src 74, dst 2266
# compute cell(0,27) src 84, dst 155
# -----Cycle----32----------
# compute cell(0,7) src 74, dst 263
# compute cell(0,10) src 71, dst 2442
# compute cell(0,12) src 74, dst 2284
# compute cell(0,21) src 74, dst 2421
# compute cell(0,22) src 76, dst 2390
# compute cell(0,25) src 74, dst 1017
# compute cell(0,27) src 84, dst 347
# -----Cycle----33----------
# compute cell(0,7) src 82, dst 295
# -----Cycle----34----------
# compute cell(0,7) src 74, dst 871
# -----Cycle----35----------
# -----Cycle----0----------
# compute cell(0,2) src 98, dst 1954
# compute cell(0,16) src 112, dst 624
# compute cell(0,30) src 126, dst 94
# -----Cycle----1----------
# compute cell(0,5) src 102, dst 1893
# compute cell(0,6) src 103, dst 294
# compute cell(0,11) src 108, dst 107
# compute cell(0,21) src 118, dst 565
# -----Cycle----2----------
# compute cell(0,11) src 109, dst 171
# compute cell(0,17) src 115, dst 1713
# compute cell(0,26) src 124, dst 122
# compute cell(0,30) src 96, dst 478
# -----Cycle----3----------
# compute cell(0,0) src 99, dst 2592
# compute cell(0,8) src 107, dst 1288
# compute cell(0,10) src 109, dst 778
# compute cell(0,11) src 110, dst 747
# compute cell(0,28) src 127, dst 124
# -----Cycle----4----------
# compute cell(0,8) src 108, dst 1288
# -----Cycle----5----------
# compute cell(0,3) src 104, dst 771
# compute cell(0,8) src 109, dst 488
# compute cell(0,9) src 110, dst 745
# compute cell(0,11) src 112, dst 747
# compute cell(0,17) src 118, dst 465
# compute cell(0,26) src 127, dst 122
# -----Cycle----6----------
# compute cell(0,0) src 102, dst 1824
# compute cell(0,7) src 109, dst 967
# compute cell(0,11) src 113, dst 747
# compute cell(0,14) src 116, dst 686
# compute cell(0,19) src 121, dst 595
# -----Cycle----7----------
# compute cell(0,0) src 103, dst 128
# compute cell(0,2) src 105, dst 2434
# compute cell(0,6) src 109, dst 2054
# compute cell(0,11) src 114, dst 171
# compute cell(0,28) src 99, dst 1852
# compute cell(0,30) src 101, dst 2686
# -----Cycle----8----------
# compute cell(0,5) src 109, dst 2053
# -----Cycle----9----------
# compute cell(0,2) src 107, dst 898
# compute cell(0,10) src 115, dst 138
# compute cell(0,14) src 119, dst 430
# compute cell(0,26) src 99, dst 1722
# compute cell(0,29) src 102, dst 2333
# -----Cycle----10----------
# compute cell(0,2) src 108, dst 898
# compute cell(0,9) src 115, dst 41
# compute cell(0,22) src 96, dst 438
# compute cell(0,23) src 97, dst 439
# compute cell(0,28) src 102, dst 2012
# -----Cycle----11----------
# compute cell(0,8) src 115, dst 904
# compute cell(0,20) src 127, dst 2228
# -----Cycle----12----------
# compute cell(0,23) src 99, dst 759
# -----Cycle----13----------
# compute cell(0,0) src 109, dst 640
# compute cell(0,18) src 127, dst 18
# compute cell(0,24) src 101, dst 1112
# -----Cycle----14----------
# compute cell(0,22) src 100, dst 758
# -----Cycle----15----------
# compute cell(0,23) src 102, dst 2583
# -----Cycle----16----------
# compute cell(0,19) src 99, dst 1619
# compute cell(0,23) src 103, dst 471
# compute cell(0,29) src 109, dst 1661
# -----Cycle----17----------
# compute cell(0,4) src 117, dst 452
# compute cell(0,7) src 120, dst 1959
# compute cell(0,11) src 124, dst 747
# compute cell(0,18) src 99, dst 2578
# compute cell(0,24) src 105, dst 248
# compute cell(0,26) src 107, dst 250
# compute cell(0,30) src 111, dst 350
# -----Cycle----18----------
# compute cell(0,9) src 123, dst 553
# compute cell(0,20) src 102, dst 404
# compute cell(0,21) src 103, dst 565
# compute cell(0,26) src 108, dst 250
# compute cell(0,27) src 109, dst 507
# -----Cycle----19----------
# compute cell(0,4) src 119, dst 228
# compute cell(0,6) src 121, dst 1990
# compute cell(0,9) src 124, dst 745
# compute cell(0,10) src 125, dst 394
# compute cell(0,13) src 96, dst 2061
# -----Cycle----20----------
# compute cell(0,1) src 117, dst 513
# compute cell(0,11) src 127, dst 747
# compute cell(0,28) src 112, dst 572
# -----Cycle----21----------
# compute cell(0,5) src 122, dst 1093
# compute cell(0,21) src 106, dst 597
# -----Cycle----22----------
# compute cell(0,9) src 127, dst 745
# compute cell(0,13) src 99, dst 1613
# compute cell(0,17) src 103, dst 465
# compute cell(0,23) src 109, dst 535
# -----Cycle----23----------
# compute cell(0,9) src 96, dst 649
# compute cell(0,23) src 99, dst 2679
# -----Cycle----24----------
# compute cell(0,0) src 120, dst 1184
# compute cell(0,1) src 121, dst 1825
# compute cell(0,11) src 99, dst 1803
# compute cell(0,28) src 116, dst 2428
# -----Cycle----25----------
# compute cell(0,11) src 100, dst 1611
# compute cell(0,18) src 107, dst 498
# compute cell(0,20) src 109, dst 884
# compute cell(0,31) src 120, dst 2175
# -----Cycle----26----------
# compute cell(0,0) src 122, dst 2400
# compute cell(0,8) src 98, dst 2696
# compute cell(0,11) src 101, dst 331
# compute cell(0,12) src 102, dst 1964
# compute cell(0,17) src 107, dst 1937
# compute cell(0,18) src 108, dst 498
# compute cell(0,27) src 117, dst 155
# compute cell(0,28) src 118, dst 636
# -----Cycle----27----------
# compute cell(0,7) src 98, dst 615
# compute cell(0,9) src 100, dst 265
# compute cell(0,14) src 105, dst 1326
# compute cell(0,18) src 109, dst 1074
# compute cell(0,31) src 122, dst 127
# -----Cycle----28----------
# compute cell(0,0) src 124, dst 2400
# compute cell(0,1) src 125, dst 1857
# compute cell(0,7) src 99, dst 1255
# compute cell(0,9) src 115, dst 2153
# compute cell(0,14) src 119, dst 686
# compute cell(0,16) src 108, dst 304
# compute cell(0,24) src 116, dst 88
# compute cell(0,25) src 117, dst 345
# compute cell(0,28) src 120, dst 188
# -----Cycle----29----------
# compute cell(0,0) src 125, dst 160
# compute cell(0,11) src 104, dst 747
# compute cell(0,16) src 109, dst 1296
# compute cell(0,24) src 101, dst 2680
# compute cell(0,31) src 124, dst 127
# -----Cycle----30----------
# compute cell(0,0) src 126, dst 2208
# compute cell(0,11) src 109, dst 459
# compute cell(0,21) src 115, dst 2421
# compute cell(0,27) src 121, dst 731
# compute cell(0,28) src 122, dst 124
# -----Cycle----31----------
# compute cell(0,0) src 127, dst 2400
# compute cell(0,7) src 102, dst 1895
# compute cell(0,11) src 109, dst 2315
# compute cell(0,12) src 107, dst 108
# compute cell(0,15) src 110, dst 687
# compute cell(0,17) src 112, dst 881
# compute cell(0,27) src 109, dst 635
# -----Cycle----32----------
# compute cell(0,0) src 109, dst 672
# compute cell(0,27) src 109, dst 955
# -----Cycle----33----------
# compute cell(0,0) src 109, dst 1888
# -----Cycle----34----------
# -----Cycle----0----------
# compute cell(0,1) src 129, dst 1409
# -----Cycle----1----------
# compute cell(0,0) src 129, dst 1728
# compute cell(0,7) src 136, dst 1479
# compute cell(0,9) src 138, dst 137
# compute cell(0,17) src 146, dst 17
# compute cell(0,28) src 157, dst 1340
# -----Cycle----2----------
# compute cell(0,0) src 130, dst 640
# compute cell(0,3) src 133, dst 611
# compute cell(0,18) src 148, dst 210
# compute cell(0,26) src 156, dst 314
# -----Cycle----3----------
# compute cell(0,5) src 136, dst 1413
# compute cell(0,11) src 142, dst 1547
# compute cell(0,14) src 145, dst 1646
# compute cell(0,17) src 148, dst 1649
# compute cell(0,28) src 159, dst 2172
# -----Cycle----4----------
# compute cell(0,11) src 143, dst 363
# compute cell(0,16) src 148, dst 656
# compute cell(0,18) src 150, dst 50
# compute cell(0,25) src 157, dst 1017
# -----Cycle----5----------
# compute cell(0,0) src 133, dst 608
# compute cell(0,2) src 135, dst 418
# compute cell(0,3) src 136, dst 1539
# compute cell(0,24) src 157, dst 2680
# compute cell(0,28) src 129, dst 188
# -----Cycle----6----------
# compute cell(0,8) src 142, dst 520
# compute cell(0,9) src 143, dst 201
# compute cell(0,11) src 145, dst 2251
# compute cell(0,21) src 155, dst 117
# compute cell(0,24) src 158, dst 184
# compute cell(0,25) src 159, dst 985
# compute cell(0,27) src 129, dst 2363
# -----Cycle----7----------
# compute cell(0,7) src 142, dst 391
# compute cell(0,11) src 146, dst 427
# compute cell(0,20) src 155, dst 84
# compute cell(0,22) src 157, dst 214
# compute cell(0,26) src 129, dst 538
# -----Cycle----8----------
# compute cell(0,6) src 142, dst 230
# compute cell(0,12) src 148, dst 460
# compute cell(0,21) src 157, dst 181
# compute cell(0,22) src 158, dst 598
# compute cell(0,30) src 134, dst 1118
# -----Cycle----9----------
# compute cell(0,0) src 137, dst 416
# compute cell(0,3) src 140, dst 323
# compute cell(0,8) src 145, dst 1224
# compute cell(0,15) src 152, dst 15
# compute cell(0,20) src 157, dst 916
# compute cell(0,31) src 136, dst 159
# -----Cycle----10----------
# compute cell(0,0) src 138, dst 416
# compute cell(0,3) src 141, dst 163
# compute cell(0,19) src 157, dst 371
# compute cell(0,26) src 132, dst 346
# -----Cycle----11----------
# compute cell(0,3) src 142, dst 227
# compute cell(0,6) src 145, dst 390
# compute cell(0,21) src 128, dst 565
# compute cell(0,22) src 129, dst 22
# -----Cycle----12----------
# compute cell(0,17) src 157, dst 2417
# compute cell(0,21) src 129, dst 1973
# compute cell(0,28) src 136, dst 92
# -----Cycle----13----------
# compute cell(0,0) src 141, dst 1184
# compute cell(0,15) src 156, dst 431
# compute cell(0,16) src 157, dst 560
# compute cell(0,17) src 158, dst 433
# compute cell(0,18) src 159, dst 2066
# compute cell(0,20) src 129, dst 1204
# compute cell(0,21) src 129, dst 2165
# compute cell(0,25) src 134, dst 505
# -----Cycle----14----------
# compute cell(0,0) src 130, dst 672
# compute cell(0,3) src 145, dst 163
# compute cell(0,11) src 153, dst 747
# compute cell(0,15) src 157, dst 2095
# compute cell(0,18) src 159, dst 2674
# compute cell(0,19) src 129, dst 2451
# compute cell(0,26) src 136, dst 986
# compute cell(0,28) src 138, dst 892
# -----Cycle----15----------
# compute cell(0,2) src 145, dst 1218
# compute cell(0,8) src 151, dst 360
# compute cell(0,12) src 155, dst 12
# compute cell(0,14) src 157, dst 78
# compute cell(0,23) src 134, dst 2135
# compute cell(0,28) src 139, dst 188
# -----Cycle----16----------
# compute cell(0,10) src 154, dst 74
# compute cell(0,12) src 156, dst 236
# compute cell(0,15) src 159, dst 2543
# compute cell(0,17) src 129, dst 2193
# compute cell(0,22) src 134, dst 1782
# -----Cycle----17----------
# compute cell(0,7) src 152, dst 1383
# compute cell(0,12) src 157, dst 716
# compute cell(0,23) src 136, dst 2231
# compute cell(0,28) src 141, dst 188
# -----Cycle----18----------
# compute cell(0,8) src 154, dst 392
# compute cell(0,15) src 129, dst 15
# compute cell(0,25) src 139, dst 2361
# -----Cycle----19----------
# compute cell(0,2) src 149, dst 66
# compute cell(0,3) src 150, dst 643
# compute cell(0,6) src 153, dst 294
# compute cell(0,9) src 156, dst 521
# compute cell(0,14) src 129, dst 2446
# -----Cycle----20----------
# compute cell(0,9) src 157, dst 393
# compute cell(0,20) src 136, dst 244
# compute cell(0,28) src 144, dst 188
# compute cell(0,31) src 147, dst 479
# -----Cycle----21----------
# compute cell(0,9) src 157, dst 1289
# compute cell(0,12) src 129, dst 2220
# compute cell(0,26) src 143, dst 346
# compute cell(0,28) src 136, dst 2172
# -----Cycle----22----------
# compute cell(0,20) src 138, dst 1716
# compute cell(0,28) src 144, dst 444
# -----Cycle----23----------
# compute cell(0,8) src 159, dst 136
# compute cell(0,11) src 130, dst 459
# compute cell(0,12) src 131, dst 76
# compute cell(0,19) src 138, dst 115
# compute cell(0,23) src 142, dst 823
# compute cell(0,26) src 145, dst 1530
# -----Cycle----24----------
# compute cell(0,5) src 157, dst 1637
# compute cell(0,8) src 145, dst 2248
# compute cell(0,16) src 136, dst 1776
# compute cell(0,19) src 157, dst 979
# compute cell(0,25) src 145, dst 2521
# compute cell(0,26) src 136, dst 1370
# -----Cycle----25----------
# compute cell(0,4) src 157, dst 740
# compute cell(0,5) src 157, dst 2021
# compute cell(0,7) src 128, dst 103
# compute cell(0,8) src 145, dst 2280
# compute cell(0,14) src 135, dst 654
# compute cell(0,15) src 136, dst 2543
# compute cell(0,17) src 138, dst 1713
# compute cell(0,19) src 157, dst 1075
# compute cell(0,24) src 145, dst 2296
# -----Cycle----26----------
# compute cell(0,1) src 155, dst 513
# compute cell(0,3) src 157, dst 2019
# compute cell(0,6) src 128, dst 294
# compute cell(0,14) src 136, dst 1102
# compute cell(0,22) src 144, dst 2102
# compute cell(0,31) src 153, dst 63
# -----Cycle----27----------
# compute cell(0,3) src 158, dst 707
# compute cell(0,6) src 142, dst 1318
# compute cell(0,10) src 133, dst 394
# compute cell(0,14) src 145, dst 2286
# compute cell(0,20) src 143, dst 180
# compute cell(0,22) src 157, dst 1718
# -----Cycle----28----------
# compute cell(0,1) src 157, dst 897
# compute cell(0,14) src 157, dst 1038
# compute cell(0,20) src 136, dst 2580
# compute cell(0,22) src 157, dst 2230
# compute cell(0,27) src 151, dst 1595
# -----Cycle----29----------
# compute cell(0,11) src 136, dst 1259
# compute cell(0,12) src 137, dst 748
# compute cell(0,14) src 157, dst 1550
# compute cell(0,23) src 148, dst 1687
# -----Cycle----30----------
# compute cell(0,3) src 129, dst 163
# compute cell(0,11) src 146, dst 747
# compute cell(0,12) src 138, dst 748
# compute cell(0,17) src 143, dst 337
# compute cell(0,23) src 136, dst 2487
# compute cell(0,31) src 157, dst 1375
# -----Cycle----31----------
# compute cell(0,3) src 142, dst 1283
# compute cell(0,10) src 137, dst 138
# compute cell(0,11) src 136, dst 2635
# compute cell(0,12) src 157, dst 1452
# compute cell(0,24) src 151, dst 1528
# compute cell(0,30) src 157, dst 766
# compute cell(0,31) src 136, dst 479
# -----Cycle----32----------
# compute cell(0,12) src 157, dst 2540
# compute cell(0,31) src 136, dst 2399
# -----Cycle----33----------
# -----Cycle----0----------
# compute cell(0,3) src 163, dst 1219
# compute cell(0,4) src 164, dst 740
# compute cell(0,17) src 177, dst 1489
# compute cell(0,28) src 188, dst 380
# -----Cycle----1----------
# compute cell(0,2) src 163, dst 290
# compute cell(0,5) src 166, dst 1125
# compute cell(0,16) src 177, dst 2192
# compute cell(0,28) src 189, dst 188
# -----Cycle----2----------
# compute cell(0,1) src 163, dst 129
# compute cell(0,15) src 177, dst 911
# compute cell(0,20) src 182, dst 468
# compute cell(0,31) src 161, dst 95
# -----Cycle----3----------
# compute cell(0,0) src 163, dst 448
# compute cell(0,14) src 177, dst 430
# compute cell(0,29) src 160, dst 125
# -----Cycle----4----------
# compute cell(0,11) src 175, dst 747
# compute cell(0,22) src 186, dst 566
# compute cell(0,24) src 188, dst 120
# compute cell(0,31) src 163, dst 191
# -----Cycle----5----------
# compute cell(0,8) src 173, dst 552
# compute cell(0,9) src 174, dst 2409
# compute cell(0,15) src 180, dst 143
# compute cell(0,30) src 163, dst 606
# -----Cycle----6----------
# compute cell(0,4) src 170, dst 4
# compute cell(0,27) src 161, dst 1147
# compute cell(0,29) src 163, dst 189
# -----Cycle----7----------
# compute cell(0,6) src 173, dst 294
# compute cell(0,17) src 184, dst 433
# compute cell(0,21) src 188, dst 757
# compute cell(0,22) src 189, dst 2102
# compute cell(0,25) src 160, dst 2681
# compute cell(0,28) src 163, dst 188
# -----Cycle----8----------
# compute cell(0,0) src 168, dst 1728
# compute cell(0,11) src 179, dst 331
# compute cell(0,16) src 184, dst 432
# compute cell(0,27) src 163, dst 219
# -----Cycle----9----------
# compute cell(0,12) src 181, dst 76
# compute cell(0,19) src 188, dst 755
# compute cell(0,22) src 191, dst 22
# compute cell(0,26) src 163, dst 346
# -----Cycle----10----------
# compute cell(0,7) src 177, dst 1959
# compute cell(0,23) src 161, dst 759
# compute cell(0,25) src 163, dst 793
# -----Cycle----11----------
# compute cell(0,2) src 173, dst 162
# compute cell(0,3) src 174, dst 163
# compute cell(0,11) src 182, dst 491
# compute cell(0,17) src 188, dst 721
# compute cell(0,21) src 160, dst 469
# compute cell(0,24) src 163, dst 856
# compute cell(0,25) src 163, dst 1113
# -----Cycle----12----------
# compute cell(0,5) src 177, dst 965
# compute cell(0,12) src 184, dst 428
# compute cell(0,16) src 188, dst 144
# compute cell(0,23) src 163, dst 55
# compute cell(0,24) src 163, dst 1784
# compute cell(0,25) src 163, dst 1305
# compute cell(0,28) src 168, dst 1756
# -----Cycle----13----------
# compute cell(0,12) src 185, dst 332
# compute cell(0,14) src 187, dst 462
# compute cell(0,22) src 163, dst 22
# compute cell(0,24) src 163, dst 2200
# compute cell(0,25) src 163, dst 1689
# compute cell(0,27) src 168, dst 475
# compute cell(0,28) src 163, dst 380
# -----Cycle----14----------
# compute cell(0,12) src 186, dst 588
# compute cell(0,21) src 163, dst 309
# compute cell(0,24) src 163, dst 2232
# compute cell(0,25) src 163, dst 2265
# compute cell(0,28) src 163, dst 1404
# compute cell(0,31) src 173, dst 575
# -----Cycle----15----------
# compute cell(0,6) src 181, dst 518
# compute cell(0,11) src 186, dst 747
# compute cell(0,13) src 188, dst 141
# compute cell(0,15) src 190, dst 2223
# compute cell(0,20) src 163, dst 2196
# compute cell(0,24) src 163, dst 2296
# compute cell(0,25) src 163, dst 2361
# compute cell(0,26) src 169, dst 570
# compute cell(0,28) src 163, dst 2204
# -----Cycle----16----------
# compute cell(0,3) src 179, dst 611
# compute cell(0,19) src 163, dst 563
# compute cell(0,25) src 163, dst 2521
# compute cell(0,26) src 170, dst 250
# compute cell(0,28) src 163, dst 2396
# -----Cycle----17----------
# compute cell(0,6) src 183, dst 454
# compute cell(0,11) src 188, dst 139
# compute cell(0,18) src 163, dst 402
# compute cell(0,27) src 172, dst 635
# -----Cycle----18----------
# compute cell(0,10) src 188, dst 42
# compute cell(0,11) src 189, dst 395
# compute cell(0,17) src 163, dst 145
# -----Cycle----19----------
# compute cell(0,0) src 179, dst 608
# compute cell(0,10) src 189, dst 42
# compute cell(0,16) src 163, dst 624
# compute cell(0,17) src 163, dst 689
# -----Cycle----20----------
# compute cell(0,5) src 185, dst 389
# compute cell(0,6) src 186, dst 294
# compute cell(0,11) src 191, dst 395
# compute cell(0,12) src 160, dst 2540
# compute cell(0,15) src 163, dst 1775
# compute cell(0,17) src 163, dst 1457
# compute cell(0,19) src 167, dst 1459
# compute cell(0,30) src 178, dst 286
# -----Cycle----21----------
# compute cell(0,2) src 183, dst 66
# compute cell(0,4) src 185, dst 324
# compute cell(0,8) src 189, dst 2664
# compute cell(0,12) src 161, dst 684
# compute cell(0,13) src 162, dst 173
# compute cell(0,14) src 163, dst 174
# compute cell(0,16) src 165, dst 432
# compute cell(0,17) src 163, dst 1905
# compute cell(0,19) src 163, dst 659
# compute cell(0,20) src 169, dst 212
# compute cell(0,27) src 176, dst 379
# -----Cycle----22----------
# compute cell(0,6) src 188, dst 262
# compute cell(0,13) src 163, dst 141
# compute cell(0,16) src 163, dst 1136
# compute cell(0,17) src 163, dst 2673
# compute cell(0,19) src 163, dst 1139
# compute cell(0,27) src 177, dst 635
# compute cell(0,30) src 180, dst 350
# -----Cycle----23----------
# compute cell(0,7) src 190, dst 519
# compute cell(0,12) src 163, dst 940
# compute cell(0,16) src 163, dst 1872
# compute cell(0,19) src 163, dst 1715
# compute cell(0,21) src 172, dst 245
# compute cell(0,22) src 173, dst 566
# compute cell(0,23) src 174, dst 503
# compute cell(0,30) src 181, dst 766
# -----Cycle----24----------
# compute cell(0,9) src 161, dst 713
# compute cell(0,11) src 163, dst 395
# compute cell(0,15) src 167, dst 559
# compute cell(0,19) src 163, dst 1971
# compute cell(0,21) src 173, dst 565
# compute cell(0,23) src 163, dst 727
# compute cell(0,26) src 178, dst 378
# compute cell(0,29) src 181, dst 157
# -----Cycle----25----------
# compute cell(0,3) src 188, dst 163
# compute cell(0,6) src 191, dst 294
# compute cell(0,10) src 163, dst 42
# compute cell(0,11) src 188, dst 523
# compute cell(0,15) src 163, dst 1807
# compute cell(0,18) src 171, dst 114
# compute cell(0,19) src 163, dst 2259
# compute cell(0,21) src 174, dst 501
# compute cell(0,23) src 163, dst 1207
# compute cell(0,26) src 163, dst 602
# -----Cycle----26----------
# compute cell(0,3) src 189, dst 163
# compute cell(0,4) src 190, dst 356
# compute cell(0,7) src 161, dst 2311
# compute cell(0,9) src 163, dst 1065
# compute cell(0,11) src 163, dst 523
# compute cell(0,18) src 163, dst 530
# compute cell(0,19) src 163, dst 2451
# compute cell(0,23) src 163, dst 1303
# compute cell(0,26) src 163, dst 1114
# compute cell(0,29) src 183, dst 541
# compute cell(0,30) src 184, dst 158
# -----Cycle----27----------
# compute cell(0,1) src 188, dst 129
# compute cell(0,7) src 162, dst 775
# compute cell(0,8) src 163, dst 744
# compute cell(0,11) src 163, dst 1099
# compute cell(0,18) src 163, dst 658
# compute cell(0,23) src 163, dst 1943
# compute cell(0,26) src 163, dst 1178
# -----Cycle----28----------
# compute cell(0,3) src 191, dst 163
# compute cell(0,7) src 163, dst 743
# compute cell(0,11) src 163, dst 1515
# compute cell(0,12) src 168, dst 2604
# compute cell(0,18) src 163, dst 1106
# compute cell(0,20) src 176, dst 756
# compute cell(0,21) src 177, dst 885
# compute cell(0,23) src 163, dst 2039
# compute cell(0,26) src 163, dst 1274
# compute cell(0,27) src 183, dst 539
# -----Cycle----29----------
# compute cell(0,3) src 163, dst 1379
# compute cell(0,4) src 161, dst 996
# compute cell(0,6) src 163, dst 390
# compute cell(0,7) src 163, dst 935
# compute cell(0,9) src 166, dst 457
# compute cell(0,10) src 167, dst 554
# compute cell(0,11) src 163, dst 1611
# compute cell(0,12) src 163, dst 2316
# compute cell(0,18) src 163, dst 1362
# compute cell(0,21) src 163, dst 757
# compute cell(0,23) src 163, dst 2295
# compute cell(0,26) src 163, dst 1498
# compute cell(0,27) src 163, dst 1467
# compute cell(0,31) src 188, dst 415
# -----Cycle----30----------
# compute cell(0,2) src 160, dst 322
# compute cell(0,3) src 163, dst 1571
# compute cell(0,5) src 163, dst 1253
# compute cell(0,6) src 163, dst 422
# compute cell(0,7) src 163, dst 1127
# compute cell(0,9) src 163, dst 1225
# compute cell(0,10) src 163, dst 266
# compute cell(0,11) src 163, dst 1675
# compute cell(0,12) src 163, dst 2604
# compute cell(0,13) src 171, dst 109
# compute cell(0,14) src 172, dst 430
# compute cell(0,18) src 163, dst 1650
# compute cell(0,21) src 173, dst 2485
# compute cell(0,26) src 163, dst 1530
# compute cell(0,27) src 163, dst 1691
# compute cell(0,31) src 163, dst 415
# -----Cycle----31----------
# compute cell(0,0) src 191, dst 448
# compute cell(0,1) src 160, dst 1857
# compute cell(0,2) src 163, dst 546
# compute cell(0,3) src 163, dst 2563
# compute cell(0,4) src 163, dst 1060
# compute cell(0,5) src 164, dst 517
# compute cell(0,6) src 163, dst 966
# compute cell(0,7) src 163, dst 1159
# compute cell(0,8) src 167, dst 552
# compute cell(0,9) src 166, dst 649
# compute cell(0,10) src 163, dst 714
# compute cell(0,11) src 163, dst 2251
# compute cell(0,13) src 188, dst 717
# compute cell(0,14) src 163, dst 910
# compute cell(0,21) src 163, dst 1205
# compute cell(0,22) src 181, dst 662
# compute cell(0,26) src 163, dst 1594
# compute cell(0,27) src 163, dst 2363
# compute cell(0,29) src 188, dst 189
# compute cell(0,31) src 163, dst 2175
# -----Cycle----32----------
# compute cell(0,0) src 163, dst 800
# compute cell(0,1) src 163, dst 769
# compute cell(0,2) src 173, dst 1378
# compute cell(0,3) src 163, dst 2659
# compute cell(0,4) src 163, dst 1380
# compute cell(0,5) src 163, dst 1573
# compute cell(0,6) src 163, dst 1030
# compute cell(0,7) src 163, dst 1575
# compute cell(0,8) src 163, dst 1224
# compute cell(0,9) src 163, dst 1257
# compute cell(0,10) src 163, dst 1098
# compute cell(0,11) src 163, dst 2667
# compute cell(0,13) src 163, dst 237
# compute cell(0,14) src 163, dst 942
# compute cell(0,21) src 163, dst 1333
# compute cell(0,22) src 163, dst 982
# compute cell(0,26) src 163, dst 1850
# compute cell(0,29) src 163, dst 765
# -----Cycle----33----------
# compute cell(0,0) src 163, dst 1536
# compute cell(0,1) src 163, dst 961
# compute cell(0,2) src 163, dst 1218
# compute cell(0,4) src 163, dst 1572
# compute cell(0,6) src 163, dst 1286
# compute cell(0,7) src 163, dst 1799
# compute cell(0,8) src 163, dst 1544
# compute cell(0,10) src 163, dst 1130
# compute cell(0,13) src 163, dst 717
# compute cell(0,14) src 163, dst 1070
# compute cell(0,21) src 163, dst 1685
# compute cell(0,22) src 163, dst 1110
# compute cell(0,26) src 163, dst 2202
# compute cell(0,29) src 163, dst 1277
# -----Cycle----34----------
# compute cell(0,0) src 163, dst 1696
# compute cell(0,1) src 163, dst 1153
# compute cell(0,2) src 163, dst 1410
# compute cell(0,4) src 163, dst 2116
# compute cell(0,6) src 163, dst 1734
# compute cell(0,7) src 163, dst 1831
# compute cell(0,8) src 163, dst 2248
# compute cell(0,13) src 163, dst 781
# compute cell(0,14) src 163, dst 2286
# compute cell(0,21) src 163, dst 1717
# compute cell(0,22) src 163, dst 1206
# compute cell(0,26) src 163, dst 2298
# compute cell(0,29) src 163, dst 2077
# -----Cycle----35----------
# compute cell(0,0) src 163, dst 1728
# compute cell(0,1) src 163, dst 1729
# compute cell(0,2) src 163, dst 1890
# compute cell(0,4) src 163, dst 2564
# compute cell(0,8) src 163, dst 2280
# compute cell(0,13) src 163, dst 813
# compute cell(0,14) src 163, dst 2638
# compute cell(0,22) src 163, dst 1334
# compute cell(0,26) src 163, dst 2554
# compute cell(0,29) src 163, dst 2173
# -----Cycle----36----------
# compute cell(0,0) src 163, dst 1792
# compute cell(0,1) src 163, dst 2177
# compute cell(0,2) src 163, dst 2274
# compute cell(0,8) src 163, dst 2600
# compute cell(0,13) src 163, dst 1069
# compute cell(0,22) src 163, dst 1558
# compute cell(0,29) src 163, dst 2557
# -----Cycle----37----------
# compute cell(0,22) src 163, dst 1590
# -----Cycle----38----------
# compute cell(0,22) src 163, dst 2518
# -----Cycle----39----------
# -----Cycle----0----------
# compute cell(0,3) src 195, dst 707
# compute cell(0,11) src 203, dst 747
# compute cell(0,26) src 218, dst 378
# -----Cycle----1----------
# compute cell(0,0) src 193, dst 192
# compute cell(0,1) src 194, dst 673
# compute cell(0,3) src 196, dst 195
# compute cell(0,11) src 204, dst 747
# compute cell(0,16) src 209, dst 2704
# compute cell(0,21) src 214, dst 469
# -----Cycle----2----------
# compute cell(0,3) src 197, dst 3
# compute cell(0,8) src 202, dst 72
# compute cell(0,10) src 204, dst 202
# compute cell(0,11) src 205, dst 427
# compute cell(0,14) src 208, dst 430
# compute cell(0,25) src 219, dst 1689
# compute cell(0,30) src 192, dst 510
# -----Cycle----3----------
# compute cell(0,6) src 201, dst 1990
# compute cell(0,12) src 207, dst 1676
# -----Cycle----4----------
# compute cell(0,7) src 203, dst 359
# compute cell(0,9) src 205, dst 745
# compute cell(0,11) src 207, dst 747
# compute cell(0,31) src 195, dst 735
# -----Cycle----5----------
# compute cell(0,3) src 200, dst 1891
# -----Cycle----6----------
# compute cell(0,19) src 217, dst 2355
# compute cell(0,21) src 219, dst 757
# -----Cycle----7----------
# compute cell(0,0) src 199, dst 640
# compute cell(0,3) src 202, dst 771
# compute cell(0,5) src 204, dst 741
# -----Cycle----8----------
# compute cell(0,3) src 203, dst 2499
# compute cell(0,14) src 214, dst 78
# compute cell(0,19) src 219, dst 563
# compute cell(0,21) src 221, dst 629
# compute cell(0,24) src 192, dst 280
# -----Cycle----9----------
# compute cell(0,7) src 208, dst 2343
# compute cell(0,12) src 213, dst 492
# compute cell(0,18) src 219, dst 402
# compute cell(0,23) src 192, dst 439
# compute cell(0,24) src 193, dst 280
# -----Cycle----10----------
# compute cell(0,4) src 206, dst 1028
# compute cell(0,8) src 210, dst 552
# compute cell(0,13) src 215, dst 2061
# -----Cycle----11----------
# compute cell(0,3) src 206, dst 1891
# compute cell(0,7) src 210, dst 295
# compute cell(0,9) src 212, dst 169
# compute cell(0,10) src 213, dst 490
# compute cell(0,11) src 214, dst 587
# compute cell(0,12) src 215, dst 2380
# compute cell(0,30) src 201, dst 350
# -----Cycle----12----------
# compute cell(0,13) src 217, dst 685
# compute cell(0,21) src 193, dst 2549
# compute cell(0,24) src 196, dst 216
# compute cell(0,25) src 197, dst 633
# -----Cycle----13----------
# compute cell(0,14) src 219, dst 846
# -----Cycle----14----------
# compute cell(0,4) src 210, dst 644
# compute cell(0,5) src 211, dst 325
# compute cell(0,11) src 217, dst 747
# compute cell(0,13) src 219, dst 1325
# -----Cycle----15----------
# compute cell(0,0) src 207, dst 1536
# compute cell(0,1) src 208, dst 1569
# compute cell(0,13) src 220, dst 45
# -----Cycle----16----------
# compute cell(0,2) src 210, dst 738
# compute cell(0,10) src 218, dst 1290
# compute cell(0,24) src 200, dst 536
# -----Cycle----17----------
# compute cell(0,10) src 219, dst 1738
# compute cell(0,14) src 223, dst 430
# -----Cycle----18----------
# compute cell(0,10) src 220, dst 490
# compute cell(0,26) src 204, dst 2650
# compute cell(0,31) src 209, dst 415
# -----Cycle----19----------
# compute cell(0,8) src 219, dst 712
# compute cell(0,14) src 193, dst 238
# compute cell(0,22) src 201, dst 1718
# compute cell(0,30) src 209, dst 2334
# compute cell(0,31) src 210, dst 63
# -----Cycle----20----------
# compute cell(0,0) src 212, dst 576
# compute cell(0,4) src 216, dst 196
# compute cell(0,8) src 220, dst 552
# compute cell(0,14) src 223, dst 686
# -----Cycle----21----------
# compute cell(0,2) src 215, dst 66
# compute cell(0,6) src 219, dst 38
# compute cell(0,7) src 220, dst 295
# compute cell(0,24) src 205, dst 600
# compute cell(0,27) src 208, dst 635
# -----Cycle----22----------
# compute cell(0,10) src 192, dst 10
# compute cell(0,24) src 206, dst 536
# -----Cycle----23----------
# compute cell(0,10) src 193, dst 10
# compute cell(0,15) src 198, dst 655
# compute cell(0,21) src 204, dst 597
# compute cell(0,28) src 211, dst 2076
# compute cell(0,30) src 213, dst 734
# -----Cycle----24----------
# compute cell(0,3) src 219, dst 163
# compute cell(0,10) src 204, dst 2410
# compute cell(0,13) src 197, dst 749
# compute cell(0,15) src 199, dst 591
# compute cell(0,24) src 208, dst 88
# -----Cycle----25----------
# compute cell(0,5) src 222, dst 581
# compute cell(0,7) src 192, dst 519
# compute cell(0,10) src 193, dst 74
# compute cell(0,19) src 204, dst 1811
# compute cell(0,29) src 214, dst 157
# compute cell(0,30) src 215, dst 478
# compute cell(0,31) src 216, dst 735
# -----Cycle----26----------
# compute cell(0,5) src 211, dst 645
# compute cell(0,7) src 193, dst 519
# compute cell(0,15) src 201, dst 143
# compute cell(0,18) src 204, dst 274
# compute cell(0,22) src 208, dst 1270
# compute cell(0,26) src 212, dst 570
# -----Cycle----27----------
# compute cell(0,3) src 222, dst 643
# compute cell(0,11) src 198, dst 747
# -----Cycle----28----------
# compute cell(0,3) src 196, dst 707
# compute cell(0,4) src 192, dst 420
# compute cell(0,18) src 206, dst 1042
# compute cell(0,23) src 211, dst 1527
# compute cell(0,30) src 218, dst 478
# -----Cycle----29----------
# compute cell(0,3) src 219, dst 2563
# compute cell(0,4) src 193, dst 420
# compute cell(0,18) src 206, dst 1490
# -----Cycle----30----------
# compute cell(0,7) src 197, dst 295
# compute cell(0,11) src 201, dst 427
# compute cell(0,12) src 202, dst 204
# compute cell(0,16) src 206, dst 1488
# compute cell(0,20) src 210, dst 148
# -----Cycle----31----------
# compute cell(0,1) src 192, dst 193
# compute cell(0,4) src 195, dst 196
# compute cell(0,11) src 202, dst 427
# compute cell(0,13) src 204, dst 1645
# compute cell(0,16) src 207, dst 688
# compute cell(0,19) src 210, dst 1459
# compute cell(0,24) src 215, dst 696
# compute cell(0,28) src 219, dst 1404
# ...
# compute cell(0,22) src 2576, dst 2678
# compute cell(0,29) src 2583, dst 2333
# -----Cycle----27----------
# compute cell(0,4) src 2590, dst 420
# compute cell(0,13) src 2568, dst 717
# compute cell(0,20) src 2575, dst 2388
# compute cell(0,23) src 2578, dst 2679
# compute cell(0,27) src 2582, dst 411
# -----Cycle----28----------
# compute cell(0,5) src 2561, dst 485
# compute cell(0,14) src 2570, dst 1806
# compute cell(0,27) src 2560, dst 2555
# -----Cycle----29----------
# compute cell(0,3) src 2560, dst 323
# compute cell(0,7) src 2564, dst 1159
# compute cell(0,25) src 2582, dst 409
# compute cell(0,26) src 2583, dst 378
# -----Cycle----30----------
# -----Cycle----31----------
# compute cell(0,1) src 2560, dst 865
# compute cell(0,3) src 2562, dst 2595
# compute cell(0,12) src 2571, dst 268
# compute cell(0,13) src 2572, dst 365
# compute cell(0,29) src 2588, dst 2301
# -----Cycle----32----------
# compute cell(0,1) src 2586, dst 2113
# -----Cycle----33----------
# compute cell(0,1) src 2560, dst 1505
# -----Cycle----34----------
# -----Cycle----0----------
# compute cell(0,2) src 2594, dst 2306
# compute cell(0,3) src 2595, dst 1315
# compute cell(0,20) src 2612, dst 724
# -----Cycle----1----------
# compute cell(0,2) src 2595, dst 2562
# compute cell(0,24) src 2617, dst 344
# -----Cycle----2----------
# compute cell(0,7) src 2601, dst 2631
# compute cell(0,20) src 2614, dst 2484
# compute cell(0,22) src 2616, dst 2614
# -----Cycle----3----------
# compute cell(0,2) src 2597, dst 1698
# -----Cycle----4----------
# compute cell(0,8) src 2604, dst 168
# compute cell(0,20) src 2616, dst 2484
# compute cell(0,25) src 2621, dst 2105
# compute cell(0,28) src 2592, dst 1852
# -----Cycle----5----------
# compute cell(0,3) src 2600, dst 163
# compute cell(0,14) src 2611, dst 2606
# compute cell(0,15) src 2612, dst 1903
# compute cell(0,20) src 2617, dst 1428
# compute cell(0,21) src 2618, dst 1269
# -----Cycle----6----------
# compute cell(0,30) src 2596, dst 2686
# -----Cycle----7----------
# compute cell(0,1) src 2600, dst 1409
# compute cell(0,6) src 2605, dst 2502
# compute cell(0,26) src 2593, dst 634
# compute cell(0,27) src 2594, dst 411
# compute cell(0,31) src 2598, dst 1631
# -----Cycle----8----------
# compute cell(0,6) src 2606, dst 2662
# compute cell(0,15) src 2615, dst 1647
# compute cell(0,20) src 2620, dst 1972
# -----Cycle----9----------
# compute cell(0,3) src 2604, dst 163
# compute cell(0,6) src 2607, dst 2310
# compute cell(0,7) src 2608, dst 519
# -----Cycle----10----------
# compute cell(0,12) src 2614, dst 1644
# compute cell(0,28) src 2598, dst 956
# -----Cycle----11----------
# compute cell(0,16) src 2619, dst 1968
# -----Cycle----12----------
# compute cell(0,3) src 2607, dst 1987
# compute cell(0,12) src 2616, dst 1644
# compute cell(0,24) src 2596, dst 2680
# compute cell(0,26) src 2598, dst 2330
# -----Cycle----13----------
# compute cell(0,1) src 2606, dst 2337
# compute cell(0,13) src 2618, dst 2509
# compute cell(0,14) src 2619, dst 1774
# compute cell(0,17) src 2622, dst 2033
# compute cell(0,31) src 2604, dst 1631
# -----Cycle----14----------
# compute cell(0,1) src 2607, dst 2369
# compute cell(0,11) src 2617, dst 2091
# -----Cycle----15----------
# compute cell(0,20) src 2595, dst 2452
# compute cell(0,28) src 2603, dst 1756
# -----Cycle----16----------
# compute cell(0,3) src 2611, dst 1763
# compute cell(0,22) src 2598, dst 854
# -----Cycle----17----------
# compute cell(0,0) src 2609, dst 2080
# compute cell(0,1) src 2610, dst 2337
# -----Cycle----18----------
# compute cell(0,26) src 2604, dst 2330
# compute cell(0,31) src 2609, dst 2079
# -----Cycle----19----------
# compute cell(0,1) src 2612, dst 2625
# compute cell(0,4) src 2615, dst 2084
# compute cell(0,8) src 2619, dst 328
# compute cell(0,14) src 2593, dst 430
# compute cell(0,26) src 2605, dst 986
# compute cell(0,27) src 2606, dst 2459
# -----Cycle----20----------
# compute cell(0,22) src 2602, dst 2070
# compute cell(0,25) src 2605, dst 1401
# -----Cycle----21----------
# compute cell(0,4) src 2617, dst 228
# compute cell(0,5) src 2618, dst 453
# compute cell(0,16) src 2597, dst 2256
# compute cell(0,18) src 2599, dst 2162
# compute cell(0,26) src 2607, dst 2074
# -----Cycle----22----------
# compute cell(0,16) src 2598, dst 1232
# compute cell(0,23) src 2605, dst 951
# -----Cycle----23----------
# compute cell(0,13) src 2596, dst 2669
# -----Cycle----24----------
# compute cell(0,14) src 2598, dst 1230
# -----Cycle----25----------
# compute cell(0,24) src 2609, dst 344
# compute cell(0,28) src 2613, dst 1756
# -----Cycle----26----------
# compute cell(0,26) src 2612, dst 26
# -----Cycle----27----------
# compute cell(0,6) src 2593, dst 2342
# compute cell(0,19) src 2606, dst 2611
# compute cell(0,21) src 2608, dst 2549
# -----Cycle----28----------
# compute cell(0,12) src 2600, dst 2220
# compute cell(0,26) src 2614, dst 986
# -----Cycle----29----------
# compute cell(0,3) src 2592, dst 99
# compute cell(0,11) src 2600, dst 523
# compute cell(0,26) src 2615, dst 2074
# -----Cycle----30----------
# compute cell(0,1) src 2623, dst 2113
# compute cell(0,24) src 2614, dst 2616
# compute cell(0,26) src 2616, dst 986
# compute cell(0,27) src 2617, dst 1275
# -----Cycle----31----------
# compute cell(0,15) src 2606, dst 527
# -----Cycle----0----------
# compute cell(0,17) src 2641, dst 1745
# compute cell(0,25) src 2649, dst 249
# -----Cycle----1----------
# compute cell(0,4) src 2629, dst 2628
# -----Cycle----2----------
# compute cell(0,0) src 2626, dst 2656
# compute cell(0,2) src 2628, dst 738
# -----Cycle----3----------
# compute cell(0,2) src 2629, dst 738
# compute cell(0,6) src 2633, dst 2182
# compute cell(0,8) src 2635, dst 136
# compute cell(0,18) src 2645, dst 2482
# compute cell(0,19) src 2646, dst 2643
# compute cell(0,29) src 2624, dst 2429
# compute cell(0,31) src 2626, dst 2399
# -----Cycle----4----------
# compute cell(0,2) src 2630, dst 1826
# -----Cycle----5----------
# -----Cycle----6----------
# -----Cycle----7----------
# compute cell(0,11) src 2642, dst 523
# -----Cycle----8----------
# compute cell(0,23) src 2655, dst 1975
# -----Cycle----9----------
# compute cell(0,21) src 2654, dst 2421
# -----Cycle----10----------
# compute cell(0,5) src 2639, dst 2117
# compute cell(0,19) src 2653, dst 1363
# compute cell(0,22) src 2624, dst 1878
# -----Cycle----11----------
# compute cell(0,3) src 2638, dst 163
# -----Cycle----12----------
# compute cell(0,16) src 2652, dst 240
# compute cell(0,20) src 2624, dst 1204
# compute cell(0,23) src 2627, dst 2423
# -----Cycle----13----------
# compute cell(0,6) src 2643, dst 2470
# compute cell(0,20) src 2625, dst 2612
# compute cell(0,31) src 2636, dst 479
# -----Cycle----14----------
# compute cell(0,12) src 2650, dst 204
# compute cell(0,27) src 2633, dst 2011
# -----Cycle----15----------
# compute cell(0,13) src 2652, dst 2637
# compute cell(0,19) src 2626, dst 1843
# compute cell(0,21) src 2628, dst 565
# -----Cycle----16----------
# compute cell(0,6) src 2646, dst 2470
# compute cell(0,11) src 2651, dst 2059
# compute cell(0,21) src 2629, dst 565
# compute cell(0,24) src 2632, dst 2584
# compute cell(0,28) src 2636, dst 2300
# -----Cycle----17----------
# compute cell(0,12) src 2653, dst 2028
# compute cell(0,28) src 2637, dst 2652
# -----Cycle----18----------
# compute cell(0,0) src 2642, dst 2368
# compute cell(0,14) src 2624, dst 2702
# -----Cycle----19----------
# compute cell(0,7) src 2650, dst 2215
# compute cell(0,13) src 2624, dst 2317
# -----Cycle----20----------
# compute cell(0,10) src 2654, dst 74
# compute cell(0,23) src 2635, dst 2231
# compute cell(0,26) src 2638, dst 2202
# -----Cycle----21----------
# compute cell(0,2) src 2647, dst 2658
# compute cell(0,4) src 2649, dst 1956
# compute cell(0,6) src 2651, dst 1062
# compute cell(0,8) src 2653, dst 456
# compute cell(0,11) src 2624, dst 1931
# compute cell(0,28) src 2641, dst 380
# -----Cycle----22----------
# compute cell(0,20) src 2634, dst 1876
# -----Cycle----23----------
# compute cell(0,1) src 2648, dst 1889
# compute cell(0,30) src 2645, dst 1854
# -----Cycle----24----------
# compute cell(0,4) src 2652, dst 2308
# -----Cycle----25----------
# compute cell(0,4) src 2649, dst 2436
# compute cell(0,30) src 2647, dst 2430
# -----Cycle----26----------
# compute cell(0,22) src 2640, dst 2070
# compute cell(0,31) src 2649, dst 735
# -----Cycle----27----------
# compute cell(0,5) src 2624, dst 2277
# -----Cycle----28----------
# -----Cycle----29----------
# compute cell(0,0) src 2653, dst 672
# compute cell(0,8) src 2629, dst 2536
# compute cell(0,13) src 2634, dst 1197
# compute cell(0,21) src 2642, dst 565
# compute cell(0,22) src 2643, dst 2646
# -----Cycle----30----------
# compute cell(0,9) src 2631, dst 2601
# compute cell(0,22) src 2644, dst 2134
# -----Cycle----31----------
# compute cell(0,5) src 2628, dst 2629
# compute cell(0,26) src 2649, dst 2106
# -----Cycle----0----------
# compute cell(0,3) src 2659, dst 163
# compute cell(0,8) src 2664, dst 712
# compute cell(0,18) src 2674, dst 2066
# compute cell(0,21) src 2677, dst 1909
# -----Cycle----1----------
# compute cell(0,27) src 2684, dst 2523
# compute cell(0,30) src 2687, dst 2174
# compute cell(0,31) src 2656, dst 799
# -----Cycle----2----------
# -----Cycle----3----------
# compute cell(0,1) src 2660, dst 577
# compute cell(0,2) src 2661, dst 2242
# compute cell(0,8) src 2667, dst 2504
# compute cell(0,15) src 2674, dst 2543
# compute cell(0,17) src 2676, dst 2385
# compute cell(0,28) src 2687, dst 636
# -----Cycle----4----------
# compute cell(0,13) src 2673, dst 2541
# -----Cycle----5----------
# compute cell(0,9) src 2670, dst 489
# compute cell(0,18) src 2679, dst 2578
# compute cell(0,29) src 2658, dst 477
# -----Cycle----6----------
# compute cell(0,16) src 2678, dst 2576
# -----Cycle----7----------
# compute cell(0,3) src 2666, dst 451
# compute cell(0,9) src 2672, dst 2409
# compute cell(0,12) src 2675, dst 1964
# compute cell(0,14) src 2677, dst 1582
# -----Cycle----8----------
# compute cell(0,3) src 2667, dst 163
# compute cell(0,30) src 2662, dst 1822
# -----Cycle----9----------
# compute cell(0,4) src 2669, dst 2596
# compute cell(0,8) src 2673, dst 1224
# compute cell(0,13) src 2678, dst 2477
# compute cell(0,31) src 2664, dst 415
# -----Cycle----10----------
# compute cell(0,8) src 2674, dst 1352
# compute cell(0,16) src 2682, dst 48
# compute cell(0,20) src 2686, dst 916
# compute cell(0,23) src 2657, dst 2423
# -----Cycle----11----------
# compute cell(0,8) src 2675, dst 1256
# compute cell(0,14) src 2681, dst 78
# compute cell(0,23) src 2658, dst 1559
# compute cell(0,29) src 2664, dst 189
# -----Cycle----12----------
# compute cell(0,15) src 2683, dst 687
# compute cell(0,22) src 2658, dst 566
# -----Cycle----13----------
# compute cell(0,6) src 2675, dst 1862
# -----Cycle----14----------
# compute cell(0,3) src 2673, dst 163
# compute cell(0,12) src 2682, dst 2348
# compute cell(0,27) src 2665, dst 2395
# compute cell(0,29) src 2667, dst 2429
# -----Cycle----15----------
# compute cell(0,19) src 2658, dst 691
# compute cell(0,22) src 2661, dst 1910
# compute cell(0,29) src 2668, dst 2365
# -----Cycle----16----------
# compute cell(0,11) src 2683, dst 427
# -----Cycle----17----------
# compute cell(0,3) src 2676, dst 611
# compute cell(0,29) src 2670, dst 253
# -----Cycle----18----------
# compute cell(0,21) src 2663, dst 1781
# compute cell(0,22) src 2664, dst 2102
# -----Cycle----19----------
# compute cell(0,0) src 2675, dst 1824
# compute cell(0,2) src 2677, dst 2338
# compute cell(0,5) src 2680, dst 101
# compute cell(0,30) src 2673, dst 638
# compute cell(0,31) src 2674, dst 159
# -----Cycle----20----------
# compute cell(0,1) src 2677, dst 2017
# compute cell(0,3) src 2679, dst 99
# compute cell(0,4) src 2680, dst 2596
# compute cell(0,23) src 2667, dst 2295
# compute cell(0,28) src 2672, dst 636
# -----Cycle----21----------
# compute cell(0,14) src 2659, dst 2030
# compute cell(0,21) src 2666, dst 2453
# -----Cycle----22----------
# compute cell(0,14) src 2660, dst 558
# compute cell(0,15) src 2661, dst 2159
# -----Cycle----23----------
# compute cell(0,6) src 2685, dst 2054
# compute cell(0,11) src 2658, dst 427
# compute cell(0,12) src 2659, dst 2316
# compute cell(0,13) src 2660, dst 1933
# compute cell(0,15) src 2662, dst 527
# compute cell(0,23) src 2670, dst 1815
# -----Cycle----24----------
# compute cell(0,1) src 2681, dst 1857
# compute cell(0,5) src 2685, dst 2053
# compute cell(0,9) src 2657, dst 1161
# compute cell(0,14) src 2662, dst 2606
# compute cell(0,23) src 2671, dst 1815
# compute cell(0,27) src 2675, dst 1595
# -----Cycle----25----------
# compute cell(0,0) src 2681, dst 160
# compute cell(0,5) src 2686, dst 101
# compute cell(0,23) src 2658, dst 2647
# compute cell(0,27) src 2676, dst 1787
# -----Cycle----26----------
# compute cell(0,4) src 2686, dst 2596
# compute cell(0,27) src 2677, dst 1339
# -----Cycle----27----------
# compute cell(0,10) src 2661, dst 2506
# compute cell(0,21) src 2672, dst 565
# compute cell(0,29) src 2680, dst 157
# -----Cycle----28----------
# compute cell(0,7) src 2659, dst 743
# compute cell(0,21) src 2663, dst 2229
# -----Cycle----29----------
# compute cell(0,3) src 2656, dst 1699
# -----Cycle----30----------
# compute cell(0,2) src 2656, dst 2626
# compute cell(0,3) src 2673, dst 995
# compute cell(0,4) src 2658, dst 1860
# compute cell(0,7) src 2661, dst 2375
# compute cell(0,13) src 2667, dst 2381
# -----Cycle----31----------
# compute cell(0,11) src 2666, dst 2411
# compute cell(0,17) src 2672, dst 465
# compute cell(0,28) src 2683, dst 668
# -----Cycle----32----------
# compute cell(0,11) src 2658, dst 843
# compute cell(0,28) src 2687, dst 764
# -----Cycle----33----------
# compute cell(0,28) src 2683, dst 2044
# -----Cycle----34----------
# -----Cycle----0----------
# compute cell(0,1) src 2689, dst 2209
# compute cell(0,18) src 2706, dst 1138
# -----Cycle----1----------
# compute cell(0,7) src 2696, dst 2695
# compute cell(0,9) src 2698, dst 2697
# compute cell(0,16) src 2705, dst 1840
# -----Cycle----2----------
# compute cell(0,9) src 2699, dst 2153
# compute cell(0,10) src 2700, dst 2698
# compute cell(0,15) src 2705, dst 1839
# -----Cycle----3----------
# compute cell(0,9) src 2700, dst 2697
# -----Cycle----4----------
# compute cell(0,2) src 2694, dst 1762
# -----Cycle----5----------
# -----Cycle----6----------
# compute cell(0,2) src 2696, dst 98
# compute cell(0,7) src 2701, dst 2247
# compute cell(0,13) src 2707, dst 1389
# -----Cycle----7----------
# compute cell(0,31) src 2694, dst 2495
# -----Cycle----8----------
# compute cell(0,0) src 2696, dst 672
# compute cell(0,24) src 2688, dst 1784
# compute cell(0,28) src 2692, dst 2172
# -----Cycle----9----------
# compute cell(0,7) src 2704, dst 2407
# compute cell(0,8) src 2705, dst 2216
# -----Cycle----10----------
# compute cell(0,5) src 2703, dst 1221
# compute cell(0,8) src 2706, dst 1640
# compute cell(0,23) src 2689, dst 1975
# compute cell(0,26) src 2692, dst 1370
# compute cell(0,31) src 2697, dst 1759
# -----Cycle----11----------
# compute cell(0,8) src 2707, dst 2344
# compute cell(0,27) src 2694, dst 571
# compute cell(0,31) src 2698, dst 1759
# -----Cycle----12----------
# compute cell(0,23) src 2691, dst 1751
# compute cell(0,27) src 2694, dst 2331
# -----Cycle----13----------
# compute cell(0,6) src 2707, dst 774
# -----Cycle----14----------
# compute cell(0,0) src 2702, dst 2624
# compute cell(0,1) src 2703, dst 1409
# compute cell(0,22) src 2692, dst 2038
# -----Cycle----15----------
# -----Cycle----16----------
# compute cell(0,16) src 2688, dst 1840
# -----Cycle----17----------
# compute cell(0,15) src 2688, dst 1839
# compute cell(0,22) src 2695, dst 2198
# -----Cycle----18----------
# -----Cycle----19----------
# compute cell(0,15) src 2690, dst 591
# -----Cycle----20----------
# compute cell(0,20) src 2696, dst 2036
# -----Cycle----21----------
# -----Cycle----22----------
# compute cell(0,23) src 2701, dst 2263
# -----Cycle----23----------
# compute cell(0,24) src 2703, dst 2200
# -----Cycle----24----------
# compute cell(0,8) src 2688, dst 2216
# -----Cycle----25----------
# compute cell(0,16) src 2697, dst 2288
# compute cell(0,24) src 2705, dst 1784
# -----Cycle----26----------
# compute cell(0,24) src 2706, dst 1752
# -----Cycle----27----------
# -----Cycle----28----------
# compute cell(0,9) src 2693, dst 2025
# compute cell(0,22) src 2706, dst 1046
# -----Cycle----29----------
# compute cell(0,5) src 2690, dst 2053
# compute cell(0,12) src 2697, dst 2700
# compute cell(0,17) src 2702, dst 881
# -----Cycle----30----------
# compute cell(0,9) src 2695, dst 2057
# compute cell(0,12) src 2698, dst 2700
# -----Cycle----31----------
# compute cell(0,8) src 2695, dst 2696
# compute cell(0,10) src 2697, dst 2698
# compute cell(0,17) src 2704, dst 209

# %%
cycle_list
# Out:
# [32,
#  33,
#  35,
#  34,
#  33,
#  39,
#  34,
#  34,
#  33,
#  34,
#  34,
#  34,
#  33,
#  36,
#  35,
#  33,
#  34,
#  39,
#  35,
#  35,
#  34,
#  33,
#  31,
#  36,
#  34,
#  32,
#  33,
#  32,
#  31,
#  32,
#  34,
#  33,
#  31,
#  34,
#  31,
#  34,
#  33,
#  34,
#  34,
#  33,
#  34,
#  34,
#  33,
#  31,
#  33,
#  34,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  33,
#  34,
#  33,
#  31,
#  35,
#  32,
#  32,
#  31,
#  32,
#  30,
#  33,
#  31,
#  32,
#  31,
#  31,
#  33,
#  33,
#  34,
#  31,
#  31,
#  33,
#  31,
#  33,
#  31,
#  31,
#  32,
#  34,
#  33,
#  34,
#  31,
#  31,
#  34,
#  31]

# %%
row_n = 32
col_n = 1
myArray = SystolicArray(row_n, col_n)

#src = [0,1,2,1,2,0,2,0,1]
#dst = [0,1,2,0,1,2,0,1,2]

#src = [0,0,0,0,1,1,2,2,2]
#dst = [0,1,3,5,2,4,0,3,5]

#src = [0,1,1,2,0,0,0,2,2]
#dst = [0,2,4,0,1,3,5,3,5]

#src = [0,1,1,2,0,1,0,2,2]
#dst = [0,2,4,0,1,3,5,4,5]

#src = [0,0,1,2]
#dst = [0,1,2,0]

#myArray.fill_edges(2708, src, dst)
myArray.edge_load_balance(row_n, src, dst)
#myArray.edge_dual_ring_boardcase(row_n, src, dst)
#idx = [0,1,2]
myArray.fill_idx(idx)
myArray.fill_result_banks(2708)       
edge_count = 0
res = myArray.run(2708)
#assert (res == np.matmul(activations, weights)).all()
#print('Systolic array matches numpy matmul')
# Out:
# -----Cycle----0----------
# compute cell(0,2) src 34, dst 66
# compute cell(0,11) src 43, dst 747
# compute cell(0,14) src 46, dst 238
# compute cell(0,20) src 52, dst 2580
# compute cell(0,28) src 60, dst 252
# -----Cycle----1----------
# compute cell(0,2) src 35, dst 34
# compute cell(0,12) src 45, dst 492
# compute cell(0,13) src 46, dst 301
# compute cell(0,26) src 59, dst 570
# -----Cycle----2----------
# compute cell(0,19) src 53, dst 243
# compute cell(0,24) src 58, dst 536
# -----Cycle----3----------
# compute cell(0,1) src 36, dst 257
# compute cell(0,10) src 45, dst 490
# -----Cycle----4----------
# compute cell(0,5) src 41, dst 1733
# compute cell(0,21) src 57, dst 565
# -----Cycle----5----------
# compute cell(0,9) src 46, dst 489
# compute cell(0,25) src 62, dst 2425
# -----Cycle----6----------
# compute cell(0,14) src 52, dst 430
# compute cell(0,17) src 55, dst 1905
# compute cell(0,19) src 57, dst 1459
# compute cell(0,25) src 63, dst 153
# -----Cycle----7----------
# compute cell(0,3) src 42, dst 163
# compute cell(0,18) src 57, dst 306
# compute cell(0,21) src 60, dst 565
# compute cell(0,26) src 33, dst 250
# -----Cycle----8----------
# -----Cycle----9----------
# compute cell(0,0) src 41, dst 352
# -----Cycle----10----------
# compute cell(0,18) src 60, dst 562
# compute cell(0,23) src 33, dst 1591
# -----Cycle----11----------
# compute cell(0,0) src 43, dst 576
# compute cell(0,3) src 46, dst 867
# compute cell(0,7) src 50, dst 583
# compute cell(0,11) src 54, dst 523
# compute cell(0,12) src 55, dst 844
# compute cell(0,16) src 59, dst 1520
# compute cell(0,27) src 38, dst 219
# compute cell(0,30) src 41, dst 94
# -----Cycle----12----------
# compute cell(0,5) src 49, dst 581
# compute cell(0,16) src 60, dst 688
# compute cell(0,22) src 34, dst 566
# compute cell(0,24) src 36, dst 2072
# -----Cycle----13----------
# compute cell(0,5) src 50, dst 581
# compute cell(0,16) src 61, dst 240
# compute cell(0,17) src 62, dst 945
# compute cell(0,18) src 63, dst 210
# compute cell(0,21) src 34, dst 565
# compute cell(0,23) src 36, dst 1591
# compute cell(0,25) src 38, dst 1689
# compute cell(0,28) src 41, dst 892
# compute cell(0,29) src 42, dst 189
# -----Cycle----14----------
# compute cell(0,3) src 49, dst 643
# compute cell(0,5) src 51, dst 645
# compute cell(0,8) src 54, dst 712
# compute cell(0,9) src 55, dst 361
# compute cell(0,10) src 56, dst 778
# compute cell(0,13) src 59, dst 1709
# compute cell(0,22) src 36, dst 1974
# compute cell(0,28) src 42, dst 188
# -----Cycle----15----------
# compute cell(0,3) src 50, dst 643
# compute cell(0,4) src 51, dst 772
# compute cell(0,7) src 54, dst 615
# compute cell(0,8) src 55, dst 1832
# compute cell(0,24) src 39, dst 24
# compute cell(0,25) src 40, dst 761
# -----Cycle----16----------
# compute cell(0,4) src 52, dst 228
# compute cell(0,25) src 41, dst 889
# compute cell(0,28) src 44, dst 2428
# -----Cycle----17----------
# compute cell(0,7) src 56, dst 967
# compute cell(0,8) src 57, dst 552
# compute cell(0,10) src 59, dst 874
# compute cell(0,24) src 41, dst 888
# compute cell(0,25) src 42, dst 793
# compute cell(0,28) src 45, dst 220
# -----Cycle----18----------
# compute cell(0,3) src 53, dst 803
# compute cell(0,7) src 57, dst 967
# compute cell(0,12) src 62, dst 332
# compute cell(0,19) src 37, dst 563
# compute cell(0,20) src 38, dst 372
# compute cell(0,23) src 41, dst 23
# -----Cycle----19----------
# compute cell(0,8) src 59, dst 872
# compute cell(0,15) src 34, dst 559
# compute cell(0,19) src 38, dst 563
# -----Cycle----20----------
# compute cell(0,3) src 55, dst 163
# compute cell(0,7) src 59, dst 839
# compute cell(0,8) src 60, dst 552
# compute cell(0,10) src 62, dst 2474
# compute cell(0,21) src 41, dst 533
# compute cell(0,24) src 44, dst 88
# compute cell(0,31) src 51, dst 2559
# -----Cycle----21----------
# compute cell(0,3) src 56, dst 1027
# compute cell(0,10) src 63, dst 1546
# compute cell(0,17) src 38, dst 273
# compute cell(0,18) src 39, dst 82
# compute cell(0,20) src 41, dst 1716
# -----Cycle----22----------
# compute cell(0,19) src 41, dst 115
# compute cell(0,26) src 48, dst 2682
# compute cell(0,30) src 52, dst 478
# compute cell(0,31) src 53, dst 1439
# -----Cycle----23----------
# compute cell(0,3) src 58, dst 1891
# compute cell(0,7) src 62, dst 423
# compute cell(0,13) src 36, dst 1933
# -----Cycle----24----------
# compute cell(0,6) src 62, dst 2566
# compute cell(0,17) src 41, dst 1713
# compute cell(0,23) src 47, dst 87
# compute cell(0,24) src 48, dst 2456
# compute cell(0,30) src 54, dst 2334
# -----Cycle----25----------
# compute cell(0,7) src 32, dst 679
# compute cell(0,23) src 48, dst 1783
# -----Cycle----26----------
# compute cell(0,4) src 62, dst 324
# compute cell(0,10) src 36, dst 1066
# compute cell(0,19) src 45, dst 1459
# compute cell(0,27) src 53, dst 1563
# -----Cycle----27----------
# compute cell(0,0) src 59, dst 576
# compute cell(0,9) src 36, dst 745
# compute cell(0,21) src 48, dst 725
# compute cell(0,31) src 58, dst 2495
# -----Cycle----28----------
# compute cell(0,3) src 63, dst 739
# compute cell(0,5) src 33, dst 1701
# compute cell(0,21) src 41, dst 725
# compute cell(0,22) src 50, dst 150
# compute cell(0,30) src 58, dst 990
# -----Cycle----29----------
# compute cell(0,22) src 36, dst 2390
# compute cell(0,23) src 52, dst 2487
# compute cell(0,30) src 41, dst 1982
# -----Cycle----30----------
# compute cell(0,14) src 44, dst 686
# -----Cycle----31----------
# compute cell(0,3) src 34, dst 35
# compute cell(0,5) src 36, dst 1701
# compute cell(0,23) src 54, dst 1687
# compute cell(0,24) src 55, dst 1784
# -----Cycle----32----------
# compute cell(0,24) src 41, dst 2456
# -----Cycle----33----------

# %%
edge_count
# Out:
# 127
